# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
statement_dates = pd.read_csv('statement_dates.csv')
spx = pd.read_csv('.\index_data\$SPX.csv',parse_dates=['Date'])

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%d%m%Y')
state_date_parse = lambda x: pd.datetime.strptime(x, '%Y%m%d')
spx['Date']=spx['Date'].apply(dateparse)

# %%
spx=spx.set_index(['Date'])

# %%
spx.drop(columns=['Open Interest','Ticker'], inplace=True)
spx = spx['2000-01-01':]

# %%
statement_dates['Statement']=np.ones(len(statement_dates))

statement_dates['Dates']=statement_dates['Dates'].apply(lambda x : str(x))

statement_dates['Dates']=statement_dates['Dates'].apply(state_date_parse)

statement_dates['Statement']=statement_dates['Statement'].apply(lambda x : int(x))

statement_dates=statement_dates.set_index(['Dates'])

# %%
spx_statements =spx.join(statement_dates, how='outer')

# %%
spx_statements = spx_statements[:'2019-03-01']

# %%
spx_statements[['Summary of Econ Projections','Statement']]=spx_statements[['Summary of Econ Projections','Statement']].fillna(0)

# %%
spx_statements.plot(y='Close',figsize=(14,8))

# %%
spx_statements['Close'].idxmin()
# Out:
# Timestamp('2009-03-09 00:00:00')

# %%
spx_statements['2010-05-08':'2010-05-12']
# Out:
#                   Open        High         Low       Close        Volume  \
# 2010-05-09         NaN         NaN         NaN         NaN           NaN
# 2010-05-10  1122.27002  1163.84998  1122.27002  1159.72998  5.925800e+09
# 2010-05-11  1156.39001  1170.47998  1147.70996  1155.79004  4.776800e+09
# 2010-05-12  1155.43005  1172.87000  1155.43005  1171.67004  4.323200e+09
#
#             Summary of Econ Projections  Statement
# 2010-05-09                          0.0        1.0
# 2010-05-10                          0.0        0.0
# 2010-05-11                          0.0        0.0
# 2010-05-12                          0.0        0.0

# %%
spx_statements['close_pct_change']=spx_statements.pct_change()['Close']

# %%
spx_statements.head()
# Out:
#                   Open        High         Low       Close        Volume  \
# 2000-01-03  1469.25000  1478.00000  1438.35999  1455.17004  1.153700e+09
# 2000-01-04  1455.21997  1455.21997  1397.43005  1399.42004  1.216500e+09
# 2000-01-05  1399.42004  1413.27002  1377.68005  1402.10999  1.422400e+09
# 2000-01-06  1402.10999  1411.90002  1392.02002  1403.44995  1.322900e+09
# 2000-01-07  1403.44995  1441.46997  1400.72998  1441.46997  1.472800e+09
#
#             Summary of Econ Projections  Statement  close_pct_change
# 2000-01-03                          0.0        0.0               NaN
# 2000-01-04                          0.0        0.0         -0.038312
# 2000-01-05                          0.0        0.0          0.001922
# 2000-01-06                          0.0        0.0          0.000956
# 2000-01-07                          0.0        0.0          0.027090

# %%
spx_statements['2010-05-08':'2010-05-12']
# Out:
#                   Open        High         Low       Close        Volume  \
# 2010-05-09         NaN         NaN         NaN         NaN           NaN
# 2010-05-10  1122.27002  1163.84998  1122.27002  1159.72998  5.925800e+09
# 2010-05-11  1156.39001  1170.47998  1147.70996  1155.79004  4.776800e+09
# 2010-05-12  1155.43005  1172.87000  1155.43005  1171.67004  4.323200e+09
#
#             Summary of Econ Projections  Statement  close_pct_change
# 2010-05-09                          0.0        1.0          0.000000
# 2010-05-10                          0.0        0.0          0.043974
# 2010-05-11                          0.0        0.0         -0.003397
# 2010-05-12                          0.0        0.0          0.013740

# %%
spx_statements['2010-05-08':'2010-05-12']
# Out:
#                   Open        High         Low       Close        Volume  \
# 2010-05-09         NaN         NaN         NaN         NaN           NaN
# 2010-05-10  1122.27002  1163.84998  1122.27002  1159.72998  5.925800e+09
# 2010-05-11  1156.39001  1170.47998  1147.70996  1155.79004  4.776800e+09
# 2010-05-12  1155.43005  1172.87000  1155.43005  1171.67004  4.323200e+09
#
#             Summary of Econ Projections  Statement  close_pct_change
# 2010-05-09                          0.0        1.0          0.000000
# 2010-05-10                          0.0        0.0          0.043974
# 2010-05-11                          0.0        0.0         -0.003397
# 2010-05-12                          0.0        0.0          0.013740

# %% [markdown]
# This date was a Sunday. Push Effects forward

# %%
pd.DataFrame(spx_statements[spx_statements['Statement']==1]['close_pct_change'].describe())
# Out:
#        close_pct_change
# count        163.000000
# mean           0.003171
# std            0.013801
# min           -0.049216
# 25%           -0.003873
# 50%            0.000911
# 75%            0.008906
# max            0.051360

# %%
pd.DataFrame(spx_statements['close_pct_change'].describe())
# Out:
#        close_pct_change
# count       4820.000000
# mean           0.000209
# std            0.012039
# min           -0.090350
# 25%           -0.004800
# 50%            0.000531
# 75%            0.005686
# max            0.115800

# %%
pd.DataFrame(spx_statements[spx_statements['Statement']==0]['close_pct_change'].describe())
# Out:
#        close_pct_change
# count       4657.000000
# mean           0.000105
# std            0.011962
# min           -0.090350
# 25%           -0.004827
# 50%            0.000524
# 75%            0.005581
# max            0.115800

# %%
fig, ax = plt.subplots(figsize=(14,8))
spx_statements[spx_statements['Statement']==1]['close_pct_change'].plot.density(ax=ax,bw_method=0.5)
spx_statements['close_pct_change'].plot.density(ax=ax,bw_method=0.5)
ax.set_xlim(-0.04,0.04)
ax.legend()

# %%
spx_nostate = spx_statements[spx_statements['Statement']==0]['close_pct_change'].dropna()
spx_yesstate=spx_statements[spx_statements['Statement']==1]['close_pct_change']

# %%
sm.stats.ttest_ind(spx_yesstate,spx_nostate)
# Out:
# (3.1992343067139366, 0.0013868628027423105, 4818.0)

# %%
spx_statements[spx_statements['Statement']==0]['close_pct_change'],
# Out:
# (2000-01-03         NaN
#  2000-01-04   -0.038312
#  2000-01-05    0.001922
#  2000-01-06    0.000956
#  2000-01-07    0.027090
#  2000-01-10    0.011190
#  2000-01-11   -0.013063
#  2000-01-12   -0.004532
#  2000-01-13    0.012318
#  2000-01-14    0.010671
#  2000-01-18   -0.006832
#  2000-01-19    0.000522
#  2000-01-20   -0.007095
#  2000-01-21   -0.002912
#  2000-01-24   -0.027530
#  2000-01-25    0.005957
#  2000-01-26   -0.004213
#  2000-01-27   -0.003938
#  2000-01-28   -0.027464
#  2000-01-31    0.025225
#  2000-02-01    0.010628
#  2000-02-03    0.011248
#  2000-02-04   -0.000421
#  2000-02-07   -0.000091
#  2000-02-08    0.012294
#  2000-02-09   -0.020836
#  2000-02-10    0.003634
#  2000-02-11   -0.020983
#  2000-02-14    0.002040
#  2000-02-15    0.008713
#                  ...
#  2019-01-16    0.002222
#  2019-01-17    0.007591
#  2019-01-18    0.013183
#  2019-01-22   -0.014157
#  2019-01-23    0.002203
#  2019-01-24    0.001376
#  2019-01-25    0.008489
#  2019-01-28   -0.007847
#  2019-01-29   -0.001456
#  2019-01-31    0.008597
#  2019-02-01    0.000899
#  2019-02-04    0.006776
#  2019-02-05    0.004708
#  2019-02-06   -0.002224
#  2019-02-07   -0.009357
#  2019-02-08    0.000676
#  2019-02-11    0.000709
#  2019-02-12    0.012890
#  2019-02-13    0.003024
#  2019-02-14   -0.002652
#  2019-02-15    0.010879
#  2019-02-19    0.001499
#  2019-02-20    0.001777
#  2019-02-21   -0.003526
#  2019-02-22    0.006411
#  2019-02-25    0.001232
#  2019-02-26   -0.000790
#  2019-02-27   -0.000544
#  2019-02-28   -0.002826
#  2019-03-01    0.006895
#  Name: close_pct_change, Length: 4658, dtype: float64,)

# %%
spx_statements[spx_statements['Statement']==1]['close_pct_change']
# Out:
# 2000-02-02   -0.000114
# 2000-03-21    0.025566
# 2000-05-16    0.009419
# 2000-06-28    0.002944
# 2000-08-22   -0.000900
# 2000-10-03   -0.006872
# 2000-11-15    0.005127
# 2000-12-19   -0.012958
# 2001-01-03    0.050099
# 2001-01-31   -0.005620
# 2001-03-20   -0.024077
# 2001-04-18    0.039143
# 2001-05-15    0.000416
# 2001-06-27   -0.004676
# 2001-08-21   -0.012079
# 2001-09-17   -0.049216
# 2001-10-02    0.012306
# 2001-11-06    0.014526
# 2001-12-11   -0.002781
# 2002-01-30    0.011748
# 2002-03-19    0.004067
# 2002-05-07   -0.003011
# 2002-06-26   -0.002684
# 2002-08-13   -0.021654
# 2002-09-24   -0.017308
# 2002-11-06    0.009133
# 2002-12-10    0.013913
# 2003-01-29    0.006791
# 2003-03-18    0.004242
# 2003-05-06    0.008462
#                 ...
# 2015-06-17    0.001980
# 2015-07-29    0.007319
# 2015-09-17   -0.002561
# 2015-10-28    0.011840
# 2015-12-16    0.014515
# 2016-01-27   -0.010863
# 2016-03-16    0.005600
# 2016-04-27    0.001649
# 2016-06-15   -0.001841
# 2016-07-27   -0.001199
# 2016-09-21    0.010917
# 2016-11-02   -0.006526
# 2016-12-14   -0.008117
# 2017-02-01    0.000298
# 2017-03-15    0.008375
# 2017-05-03   -0.001271
# 2017-06-14   -0.000996
# 2017-07-26    0.000283
# 2017-09-20    0.000634
# 2017-11-01    0.001592
# 2017-12-13   -0.000473
# 2018-01-31    0.000489
# 2018-03-21   -0.001844
# 2018-05-02   -0.007206
# 2018-06-13   -0.004026
# 2018-08-01   -0.001040
# 2018-09-26   -0.003289
# 2018-11-08   -0.002509
# 2018-12-19   -0.015396
# 2019-01-30    0.015549
# Name: close_pct_change, Length: 163, dtype: float64

# %%
poli_leader = pd.DataFrame({'Date':spx_statements.index})

# %%
def chairperson(x):
    if '2006-01-31'>=str(x)>='2000-01-01':
        return 'Greenspan'
    elif '2014-01-31'>=str(x)>='2006-02-01':
        return 'Bernanke'
    elif '2018-02-03'>=str(x)>='2014-02-03':
        return 'Yellen'
    else: 
        return 'Powell'
    
def president(x):
    if '2001-01-20'>str(x)>='2000-01-01':
        return 'Clinton'
    elif '2009-01-20'>str(x)>='2001-01-20':
        return 'Bush'
    elif '2017-01-20'>str(x)>='2009-01-20':
        return 'Obama'
    else: 
        return 'Trump'

# %%
poli_leader['fed_chair']=poli_leader['Date'].apply(chairperson)
poli_leader['president']=poli_leader['Date'].apply(president)

# %%
poli_leader.head()
# Out:
#             fed_chair president
# Date
# 2000-01-03  Greenspan   Clinton
# 2000-01-04  Greenspan   Clinton
# 2000-01-05  Greenspan   Clinton
# 2000-01-06  Greenspan   Clinton
# 2000-01-07  Greenspan   Clinton

# %%
poli_leader = poli_leader.set_index(['Date'])

# %%
poli_leader[['fed_chair','president']]=poli_leader[['fed_chair','president']].astype('category')

# %%
poli_leader['fed_chair']
# Out:
# Date
# 2000-01-03    Greenspan
# 2000-01-04    Greenspan
# 2000-01-05    Greenspan
# 2000-01-06    Greenspan
# 2000-01-07    Greenspan
# 2000-01-10    Greenspan
# 2000-01-11    Greenspan
# 2000-01-12    Greenspan
# 2000-01-13    Greenspan
# 2000-01-14    Greenspan
# 2000-01-18    Greenspan
# 2000-01-19    Greenspan
# 2000-01-20    Greenspan
# 2000-01-21    Greenspan
# 2000-01-24    Greenspan
# 2000-01-25    Greenspan
# 2000-01-26    Greenspan
# 2000-01-27    Greenspan
# 2000-01-28    Greenspan
# 2000-01-31    Greenspan
# 2000-02-01    Greenspan
# 2000-02-02    Greenspan
# 2000-02-03    Greenspan
# 2000-02-04    Greenspan
# 2000-02-07    Greenspan
# 2000-02-08    Greenspan
# 2000-02-09    Greenspan
# 2000-02-10    Greenspan
# 2000-02-11    Greenspan
# 2000-02-14    Greenspan
#                 ...
# 2019-01-17       Powell
# 2019-01-18       Powell
# 2019-01-22       Powell
# 2019-01-23       Powell
# 2019-01-24       Powell
# 2019-01-25       Powell
# 2019-01-28       Powell
# 2019-01-29       Powell
# 2019-01-30       Powell
# 2019-01-31       Powell
# 2019-02-01       Powell
# 2019-02-04       Powell
# 2019-02-05       Powell
# 2019-02-06       Powell
# 2019-02-07       Powell
# 2019-02-08       Powell
# 2019-02-11       Powell
# 2019-02-12       Powell
# 2019-02-13       Powell
# 2019-02-14       Powell
# 2019-02-15       Powell
# 2019-02-19       Powell
# 2019-02-20       Powell
# 2019-02-21       Powell
# 2019-02-22       Powell
# 2019-02-25       Powell
# 2019-02-26       Powell
# 2019-02-27       Powell
# 2019-02-28       Powell
# 2019-03-01       Powell
# Name: fed_chair, Length: 4821, dtype: category
# Categories (4, object): [Bernanke, Greenspan, Powell, Yellen]

# %%
spx_statements=spx_statements.join(poli_leader,how='inner')

# %%
spx_statements[spx_statements['Summary of Econ Projections']==1]['close_pct_change'].describe()
# Out:
# count    46.000000
# mean      0.004151
# std       0.009732
# min      -0.015396
# 25%      -0.002382
# 50%       0.003949
# 75%       0.010358
# max       0.033558
# Name: close_pct_change, dtype: float64

# %%
from pandas.plotting import autocorrelation_plot

# %%
plt.figure(figsize=(14,8))
sm.graphics.tsa.plot_acf(spx_statements['Close'])

# %%
spx_statements['Close'].autocorr(lag=2000)
# Out:
# 0.04416085969607247

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(spx_statements['close_pct_change'])

# %%
lag_plot(spx_statements['Close'])

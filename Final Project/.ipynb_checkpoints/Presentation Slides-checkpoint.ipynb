# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # FOMC Statements, Sentiment and the US Stock Market
# ##
# ### By Michael Mak

# %%
plt.style.use('ggplot')

# %%
spx_statements = pd.read_csv('dataset.csv',parse_dates=['index'])
spx_statements=spx_statements.set_index(['index'])

# %%
spx_statements.plot(y='Close',figsize=(14,8))

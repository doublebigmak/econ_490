# %%
from textblob import TextBlob
import csv
import pandas as pd
import os

# %%
path= './scraped_data/'
files = os.listdir(path)
polarity = []
subjectivity = []
for i in files:
    if i[-3:] =='csv':
        
        with open(path+i) as f:
            s = f.read()

        blob=TextBlob(s)
        
        polarity.append(blob.sentiment.polarity)
        subjectivity.append(blob.sentiment.subjectivity)

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
polarity
# Out:
# [0.058333333333333334,
#  0.08037449971412237,
#  0.14405594405594405,
#  0.35000000000000003,
#  0.09166666666666667,
#  -0.075,
#  0.1256198347107438,
#  0.33349282296650723,
#  0.075,
#  0.10096995055154054,
#  0.17272727272727273,
#  0.4,
#  0.6,
#  0.27878787878787875,
#  -0.00028409090909090696,
#  0.1176948051948051,
#  0.31,
#  0.023095238095238092,
#  0.19308558558558567,
#  0.13232974910394266,
#  0.15756392045454543,
#  0.14987468671679194,
#  0.15530158730158736,
#  0.08444444444444445,
#  0.09521531100478468,
#  -0.06749999999999999,
#  0.175,
#  0.03995416348357522,
#  -0.0787037037037037,
#  0.1723402523402524,
#  0.06108508977361438,
#  0.13108571428571428,
#  0.06108508977361438,
#  0.1285885167464115,
#  0.2857142857142857,
#  0.1433823529411765,
#  0.09542483660130718,
#  0.11755227476925595,
#  0.30833333333333335,
#  0.09826945412311275,
#  0.029824561403508764,
#  0.06484724292101339,
#  0.02564102564102564,
#  0.09937417654808957,
#  0.2,
#  0.09855475264035536,
#  0.12695035460992912,
#  0.15039682539682542,
#  0.03571428571428571,
#  0.1871351766513057,
#  0.08333333333333333,
#  0.23848148148148143,
#  0.1447638983823194,
#  0.07352941176470588,
#  0.022696139476961395,
#  0.1844028520499109,
#  0.1544903013653013,
#  0.03459145021645018,
#  -0.0787037037037037,
#  0.23277777777777778,
#  0.04036363636363636,
#  0.10272727272727274,
#  0.0807017543859649,
#  -0.05416666666666667,
#  0.0,
#  0.13264462809917354,
#  0.08994708994708994,
#  0.13260188087774297,
#  0.06071428571428572,
#  0.05813131313131312,
#  0.1425,
#  0.05687830687830689,
#  0.11647869674185463,
#  0.17250329380764168,
#  -0.05357142857142857,
#  0.13459595959595963,
#  0.14705638474295185,
#  0.0,
#  0.12676767676767678,
#  0.0,
#  0.09877541650268921,
#  0.0,
#  0.06125541125541126,
#  0.16,
#  0.1425299506694856,
#  0.18893442622950818,
#  0.0,
#  0.18333333333333332,
#  0.023255813953488372,
#  0.12065295815295805,
#  0.21200000000000008,
#  0.0,
#  0.0,
#  -0.034722222222222224,
#  -0.03125,
#  -0.024675324675324677,
#  0.10505050505050505,
#  0.14573863636363638,
#  0.2318181818181818,
#  0.0,
#  0.0,
#  0.11097560975609756,
#  0.0,
#  0.10714285714285716,
#  0.0,
#  0.0,
#  0.11207897793263648,
#  0.0,
#  0.12269503546099289,
#  0.0,
#  0.1590909090909091,
#  0.6,
#  0.0,
#  0.1677018633540373,
#  0.0,
#  0.09852897911150343,
#  0.1675,
#  0.0,
#  0.12623376623376623,
#  0.0,
#  -0.004545454545454543,
#  0.0,
#  0.0,
#  0.06895223420647151,
#  0.0,
#  0.0,
#  0.0576923076923077,
#  0.0,
#  0.06944444444444446,
#  0.0,
#  0.06944444444444446,
#  0.0,
#  0.031707317073170746,
#  0.0,
#  0.02165071770334928,
#  0.0,
#  0.02822966507177034,
#  0.0,
#  0.03437500000000001,
#  0.0,
#  0.0,
#  0.03438416422287391,
#  0.0,
#  0.051319648093841645,
#  0.041642228739002946,
#  0.0374331550802139,
#  0.2333333333333333,
#  0.04917976760082023,
#  0.03936613844870727,
#  0.1041125541125541,
#  0.2625,
#  0.10165289256198343,
#  0.07272727272727272,
#  0.1,
#  0.1041125541125541,
#  0.06822966507177035,
#  0.1,
#  0.0,
#  -0.03333333333333333,
#  0.0707912457912458,
#  0.3,
#  0.11538461538461539,
#  0.0,
#  0.0733451015004413,
#  0.11538461538461539,
#  0.0,
#  0.05595611285266459,
#  0.125,
#  0.0,
#  0.0492822966507177,
#  0.35,
#  -0.05555555555555555,
#  0.125,
#  0.0,
#  0.09581252081252081,
#  0.35,
#  0.125,
#  0.0,
#  0.10085638998682478,
#  0.35,
#  0.125,
#  0.0,
#  0.07936125965537733,
#  0.35,
#  0.125,
#  0.0,
#  0.06487179487179487,
#  0.125,
#  0.0,
#  0.041,
#  0.125,
#  0.0,
#  0.04863636363636364,
#  0.125,
#  0.0,
#  0.04115384615384616,
#  0.14285714285714285,
#  0.0,
#  0.050769230769230775,
#  0.125,
#  0.0,
#  -0.008749999999999996,
#  0.125,
#  0.0,
#  0.020666666666666667,
#  0.125,
#  0.0,
#  0.0,
#  0.037843137254901967,
#  0.125,
#  0.0,
#  0.03063492063492064,
#  0.08571428571428573,
#  0.1152972027972028,
#  0.125,
#  0.0,
#  0.07864219114219115,
#  0.6,
#  0.6,
#  0.125,
#  0.0,
#  0.035227272727272725,
#  0.6,
#  0.07058823529411763,
#  0.05,
#  0.0,
#  0.0564935064935065,
#  0.05316666666666668,
#  0.35,
#  0.041666666666666664,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.08333333333333333,
#  -0.0071428571428571435,
#  0.0,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.05375,
#  0.6,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.04056818181818182,
#  0.6,
#  -0.027083333333333334,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.08214285714285716,
#  0.041666666666666664,
#  0.09999999999999999,
#  -0.05083333333333333,
#  0.10765306122448981,
#  0.041666666666666664,
#  0.05339903459372487,
#  0.0,
#  0.6,
#  0.03633449883449883,
#  0.4333333333333333,
#  0.35,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.0,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.0,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.02044111061352441,
#  0.6,
#  0.04565217391304348,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.08214285714285716,
#  0.0,
#  0.0,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.04593167701863355,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.08636363636363636,
#  0.0,
#  0.041666666666666664,
#  0.08571428571428572,
#  0.10698824984539274,
#  0.05565714285714287,
#  0.027777777777777776,
#  0.08571428571428572,
#  0.08571428571428572,
#  0.027777777777777776,
#  0.08571428571428572,
#  0.0,
#  0.027777777777777776,
#  0.08571428571428572,
#  0.08571428571428572,
#  0.058015873015873014,
#  0.029454545454545452,
#  0.13333333333333333,
#  0.027777777777777776,
#  0.08571428571428572,
#  0.00647382920110193,
#  0.008712121212121216,
#  0.08511422570828513,
#  0.13204643841007477,
#  0.08333333333333333,
#  0.06249122807017546,
#  0.0734375,
#  0.11869351408825093,
#  0.041666666666666664,
#  -0.0045155638012780875,
#  0.12030303030303031,
#  0.012993777056277056,
#  0.10547409579667646,
#  0.6,
#  0.35,
#  0.04411764705882353,
#  0.0923076923076923,
#  0.00696969696969697,
#  0.041666666666666664,
#  0.0923076923076923,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.07307692307692308,
#  -0.1111111111111111,
#  0.041666666666666664,
#  0.011208389311837591,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.0,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.6,
#  0.35,
#  0.027631578947368424,
#  0.041666666666666664,
#  0.10952380952380951,
#  0.08333333333333333,
#  0.06409582841401022,
#  -0.0016666666666666746,
#  0.09999999999999999,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.09060714285714286,
#  0.050396825396825405,
#  0.0272108843537415,
#  0.07008797653958945,
#  0.03209647495361781,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.03541666666666668,
#  0.17240740740740745,
#  0.041666666666666664,
#  0.0,
#  0.08246901500326158,
#  0.041666666666666664,
#  0.09999999999999999,
#  -0.041666666666666664,
#  0.10102813852813854,
#  0.07937062937062936,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.03452611218568665,
#  0.09999999999999999,
#  0.08333333333333333,
#  0.0,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.1014800514800515,
#  0.042099567099567095,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.07307692307692308,
#  0.0,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.0,
#  0.1020212630506748,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.028273809523809527,
#  0.11421030210923826,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.07307692307692308,
#  0.0,
#  0.125,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.04013605442176871,
#  0.06469381313131313,
#  0.34659090909090906,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.0,
#  0.08333333333333333,
#  0.04666666666666666,
#  0.09999999999999999,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.01743697478991597,
#  0.07311165845648604,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.08333333333333333,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.03568376068376069,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.07307692307692308,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.08520979020979022,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.09516806722689075,
#  0.09999999999999999,
#  0.08333333333333333,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.07987405106970326,
#  0.041666666666666664,
#  0.09999999999999999,
#  0.07307692307692308,
#  0.1781746031746032,
#  0.0,
#  0.04833333333333334,
#  0.09999999999999999,
#  0.08456766917293233,
#  0.08333333333333333,
#  0.0,
#  0.08259398496240603,
#  0.19345238095238096,
#  0.028333333333333335,
#  0.11875,
#  0.0057392102846648314,
#  0.07307692307692308,
#  0.0,
#  0.11374999999999999,
#  0.012499999999999997,
#  0.03333333333333333,
#  0.06629551820728291,
#  -0.00714285714285715,
#  0.05,
#  -0.00714285714285715,
#  0.03333333333333333,
#  0.07307692307692308,
#  0.22349282296650716,
#  0.059900793650793656,
#  0.08333333333333333,
#  0.0,
#  -0.0109375,
#  0.07090187590187591,
#  0.012499999999999997,
#  0.03333333333333333,
#  0.08333333333333333,
#  0.0,
#  0.07331909318751424,
#  0.07307692307692308,
#  0.012499999999999997,
#  0.0,
#  0.0625631313131313,
#  0.09215913715913718,
#  0.030555555555555558,
#  0.08333333333333333,
#  0.0,
#  0.09994397759103643,
#  0.012499999999999997,
#  0.05,
#  0.07307692307692308,
#  0.0,
#  0.08240740740740743,
#  0.00928030303030303,
#  0.0,
#  0.012499999999999997,
#  0.08333333333333333,
#  0.0,
#  0.08865740740740742,
#  0.07307692307692308,
#  0.0,
#  0.040624999999999994,
#  0.03333333333333333,
#  0.08137254901960783,
#  0.05555555555555555,
#  0.034375,
#  0.07307692307692308,
#  0.0,
#  0.05277777777777778,
#  0.03333333333333333,
#  0.08125000000000002,
#  0.08333333333333333,
#  0.0,
#  0.040624999999999994,
#  0.05,
#  0.08018518518518519,
#  0.08333333333333333,
#  0.0,
#  0.07039473684210527,
#  0.05277777777777778,
#  0.03333333333333333,
#  0.07307692307692308,
#  0.0,
#  0.04813248766737139,
#  0.09436274509803924,
#  0.08333333333333333,
#  0.05277777777777778,
#  0.0,
#  0.125,
#  0.08247747747747751,
#  0.07307692307692308,
#  0.0,
#  0.06313492063492067,
#  0.05277777777777778,
#  0.03333333333333333,
#  0.08333333333333333,
#  0.0,
#  0.07600775193798452,
#  0.040624999999999994,
#  0.03333333333333333,
#  0.07307692307692308,
#  0.0,
#  0.07003703703703706,
#  0.1324505928853755,
#  0.05277777777777778,
#  0.0,
#  0.06525362318840582,
#  0.08333333333333333,
#  0.0,
#  0.05277777777777778,
#  0.05,
#  0.10340425531914894,
#  0.023217468805704106,
#  0.1125,
#  0.0,
#  0.13732026143790851,
#  0.05277777777777778,
#  0.03333333333333333,
#  0.02972027972027972,
#  0.0,
#  0.11021756978653531,
#  0.009848484848484855,
#  0.1125,
#  0.0,
#  0.05277777777777778,
#  0.03333333333333333,
#  0.1115859564164649,
#  0.08333333333333333,
#  0.0,
#  0.05277777777777778,
#  0.03333333333333333,
#  0.04999999999999999,
#  0.11685230024213077,
#  0.0,
#  0.1125,
#  0.0,
#  0.1722222222222222,
#  0.12972431077694238,
#  0.07999999999999999,
#  0.15,
#  0.08333333333333333,
#  0.0,
#  0.13628415300546448,
#  0.1125,
#  0.15,
#  0.12480225988700566,
#  0.08333333333333333,
#  0.0,
#  0.07999999999999999,
#  0.15,
#  0.09572463768115944,
#  0.08333333333333333,
#  0.0,
#  0.10448529411764708,
#  0.03627450980392157,
#  0.07999999999999999,
#  0.15,
#  0.08333333333333333,
#  0.0,
#  0.10554444444444444,
#  0.07999999999999999,
#  0.15,
#  0.10594047619047622,
#  0.08333333333333333,
#  0.11666666666666665,
#  0.0,
#  0.09166666666666666,
#  0.05,
#  0.09166666666666666,
#  0.05,
#  0.09166666666666666,
#  0.05,
#  0.1015983606557377,
#  0.1388888888888889,
#  0.13333333333333333,
#  0.10454545454545454,
#  0.0,
#  0.10238536155202824,
#  0.0625,
#  0.09166666666666666,
#  0.03333333333333333,
#  0.08333333333333333,
#  0.09166666666666666,
#  0.0,
#  0.05,
#  0.09166666666666666,
#  0.34659090909090906,
#  0.09166666666666666,
#  0.05,
#  0.09166666666666666,
#  0.05,
#  0.099125,
#  0.09166666666666666,
#  0.05,
#  0.09166666666666666,
#  0.05,
#  0.09166666666666666,
#  0.05,
#  0.10454545454545454,
#  0.0,
#  0.11543650793650793,
#  0.08333333333333333,
#  0.0,
#  0.03630952380952381,
#  0.10764285714285715,
#  0.10454545454545454,
#  0.05222222222222222,
#  0.0,
#  0.03333333333333333,
#  0.05222222222222222,
#  0.03333333333333333,
#  0.057843137254901957,
#  0.05,
#  0.06734800838574424,
#  0.05222222222222222,
#  0.05,
#  0.050438596491228074,
#  0.03333333333333333,
#  0.052916666666666654,
#  0.05,
#  0.08333333333333333,
#  0.05222222222222222,
#  0.0,
#  0.05222222222222222,
#  0.03333333333333333,
#  0.07574404761904763,
#  0.10454545454545454,
#  0.0,
#  0.07892316017316017,
#  0.04848484848484849,
#  0.05588235294117647,
#  0.16,
#  0.05588235294117647,
#  0.16,
#  0.08333333333333333,
#  0.16,
#  0.0,
#  0.08599896480331264,
#  0.10454545454545454,
#  0.0,
#  0.12161111111111113,
#  0.0,
#  0.06999999999999999,
#  0.08333333333333333,
#  0.16,
#  0.0,
#  0.05588235294117647,
#  0.16,
#  0.10179924242424243,
#  0.10454545454545454,
#  0.0,
#  0.12125,
#  0.10116279069767443,
#  0.06153846153846154,
#  0.05588235294117647,
#  0.16,
#  0.05588235294117647,
#  0.16,
#  0.08333333333333333,
#  0.0,
#  0.099,
#  0.10454545454545454,
#  0.0,
#  0.10833333333333334,
#  0.08333333333333333,
#  0.048717948717948725,
#  0.0,
#  0.05588235294117647,
#  0.16,
#  0.051781970649895176,
#  0.3666666666666667,
#  0.10454545454545454,
#  0.0,
#  0.03934294871794871,
#  0.048717948717948725,
#  0.08333333333333333,
#  0.16,
#  0.0,
#  0.04529320987654321,
#  0.08333333333333333,
#  0.0,
#  0.05011217948717949,
#  0.05833333333333333,
#  0.08333333333333333,
#  0.16,
#  0.0,
#  0.0404891304347826,
#  -0.0225,
#  0.0,
#  0.10454545454545454,
#  0.0,
#  0.048688271604938264,
#  0.05833333333333333,
#  0.16,
#  0.08333333333333333,
#  0.0,
#  0.04283625730994152,
#  0.10454545454545454,
#  0.05833333333333333,
#  0.0,
#  0.16,
#  0.03811728395061728,
#  0.08333333333333333,
#  0.0,
#  0.038480392156862726,
#  0.3666666666666667,
#  0.10454545454545454,
#  0.0,
#  0.041927083333333316,
#  0.05833333333333333,
#  0.08333333333333333,
#  0.16,
#  0.0,
#  0.07781385281385281,
#  0.021306818181818187,
#  0.3666666666666667,
#  0.10454545454545454,
#  0.0,
#  0.04374999999999998,
#  0.05833333333333333,
#  0.16,
#  0.08333333333333333,
#  0.0,
#  0.0267857142857143,
#  0.37878787878787873,
#  0.0,
#  0.10454545454545454,
#  0.0,
#  0.025625000000000016,
#  0.05833333333333333,
#  0.16,
#  0.08333333333333333,
#  0.0,
#  0.02627551020408164,
#  0.10454545454545454,
#  0.0675438596491228,
#  0.0,
#  0.16,
#  0.024728260869565227,
#  0.08333333333333333,
#  0.0,
#  0.04668560606060604,
#  0.5,
#  0.10454545454545454,
#  0.0,
#  0.040345528455284545,
#  0.08333333333333333,
#  0.0,
#  0.05914855072463767,
#  0.5,
#  0.10454545454545454,
#  0.0,
#  0.06313405797101448,
#  0.04652777777777778,
#  0.16,
#  0.08333333333333333,
#  0.0,
#  0.0,
#  0.08002450980392156,
#  0.3090909090909091,
#  0.10454545454545454,
#  0.0,
#  0.09297619047619048,
#  0.0675438596491228,
#  0.08333333333333333,
#  0.16,
#  0.0,
#  0.0779040404040404,
#  0.37878787878787873,
#  0.10454545454545454,
#  0.0,
#  0.0779040404040404,
#  0.18295454545454543,
#  0.08333333333333333,
#  0.0,
#  0.07817982456140352,
#  0.37878787878787873,
#  0.10454545454545454,
#  0.0,
#  0.08942307692307692,
#  0.08333333333333333,
#  0.0]

# %%
sentiment = pd.DataFrame({'Polarity':polarity,'Subjectivity':subjectivity})

# %%
sentiment.describe()
# Out:
#          Polarity  Subjectivity
# count  814.000000    814.000000
# mean     0.080884      0.285100
# std      0.096597      0.160049
# min     -0.111111      0.000000
# 25%      0.029521      0.219160
# 50%      0.067446      0.294379
# 75%      0.101014      0.390060
# max      0.600000      0.800000

# %%
blob
# Out:
# TextBlob(""The Federal Reserve Board on Tuesday released the minutes of its interest rate meetings on January 22 and January 30, 2019.","The minutes are attached.","For media inquiries, call 202-452-2955.","20190226"
#
# ")

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
#from textblob.classifiers import NaiveBayesClassifier

# %%
from textblob import TextBlob
from textblob import Blobber
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\makmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open('./scraped_data/20080122.csv') as f:
    s = f.read()

    blob=TextBlob(s)

# %%
blob.sentences[:]
# Out:
# [Sentence(""The Federal Open Market Committee has decided to lower its target for the federal funds rate 75 basis points to 3-1/2 percent."),
#  Sentence("","The Committee took this action in view of a weakening of the economic outlook and increasing downside risks to growth."),
#  Sentence("While strains in short-term funding markets have eased somewhat, broader financial market conditions have continued to deteriorate and credit has tightened further for some businesses and households."),
#  Sentence("Moreover, incoming information indicates a deepening of the housing contraction as well as some softening in labor markets."),
#  Sentence("","The Committee expects inflation to moderate in coming quarters, but it will be necessary to continue to monitor inflation developments carefully."),
#  Sentence("","Appreciable downside risks to growth remain."),
#  Sentence("The Committee will continue to assess the effects of financial and other developments on economic prospects and will act in a timely manner as needed to address those risks."),
#  Sentence("","Voting for the FOMC monetary policy action were: Ben S. Bernanke, Chairman; Timothy F. Geithner, Vice Chairman; Charles L. Evans; Thomas M. Hoenig; Donald L. Kohn; Randall S. Kroszner; Eric S. Rosengren; and Kevin M. Warsh."),
#  Sentence("Voting against was William Poole, who did not believe that current conditions justified policy action before the regularly scheduled meeting next week."),
#  Sentence("Absent and not voting was Frederic S."),
#  Sentence("Mishkin."),
#  Sentence("","In a related action, the Board of Governors approved a 75-basis-point decrease in the discount rate to 4 percent."),
#  Sentence("In taking this action, the Board approved the requests submitted by the Boards of Directors of the Federal Reserve Banks of Chicago and Minneapolis."),
#  Sentence("","20080122"")]

# %%
blob
# Out:
# TextBlob(""The Federal Open Market Committee has decided to lower its target for the federal funds rate 75 basis points to 3-1/2 percent.","The Committee took this action in view of a weakening of the economic outlook and increasing downside risks to growth. While strains in short-term funding markets have eased somewhat, broader financial market conditions have continued to deteriorate and credit has tightened further for some businesses and households. Moreover, incoming information indicates a deepening of the housing contraction as well as some softening in labor markets.","The Committee expects inflation to moderate in coming quarters, but it will be necessary to continue to monitor inflation developments carefully.","Appreciable downside risks to growth remain. The Committee will continue to assess the effects of financial and other developments on economic prospects and will act in a timely manner as needed to address those risks. ","Voting for the FOMC monetary policy action were: Ben S. Bernanke, Chairman; Timothy F. Geithner, Vice Chairman; Charles L. Evans; Thomas M. Hoenig; Donald L. Kohn; Randall S. Kroszner; Eric S. Rosengren; and Kevin M. Warsh. Voting against was William Poole, who did not believe that current conditions justified policy action before the regularly scheduled meeting next week. Absent and not voting was Frederic S. Mishkin.","In a related action, the Board of Governors approved a 75-basis-point decrease in the discount rate to 4 percent. In taking this action, the Board approved the requests submitted by the Boards of Directors of the Federal Reserve Banks of Chicago and Minneapolis.","20080122"
#
# ")

# %%
word_list = [word.lemmatize().upper() for word in blob.words]

# %%
word_list
# Out:
# ['THE',
#  'FEDERAL',
#  'OPEN',
#  'MARKET',
#  'COMMITTEE',
#  'HA',
#  'DECIDED',
#  'TO',
#  'LOWER',
#  'IT',
#  'TARGET',
#  'FOR',
#  'THE',
#  'FEDERAL',
#  'FUND',
#  'RATE',
#  '75',
#  'BASIS',
#  'POINT',
#  'TO',
#  '3-1/2',
#  'PERCENT',
#  'THE',
#  'COMMITTEE',
#  'TOOK',
#  'THIS',
#  'ACTION',
#  'IN',
#  'VIEW',
#  'OF',
#  'A',
#  'WEAKENING',
#  'OF',
#  'THE',
#  'ECONOMIC',
#  'OUTLOOK',
#  'AND',
#  'INCREASING',
#  'DOWNSIDE',
#  'RISK',
#  'TO',
#  'GROWTH',
#  'WHILE',
#  'STRAIN',
#  'IN',
#  'SHORT-TERM',
#  'FUNDING',
#  'MARKET',
#  'HAVE',
#  'EASED',
#  'SOMEWHAT',
#  'BROADER',
#  'FINANCIAL',
#  'MARKET',
#  'CONDITION',
#  'HAVE',
#  'CONTINUED',
#  'TO',
#  'DETERIORATE',
#  'AND',
#  'CREDIT',
#  'HA',
#  'TIGHTENED',
#  'FURTHER',
#  'FOR',
#  'SOME',
#  'BUSINESS',
#  'AND',
#  'HOUSEHOLD',
#  'MOREOVER',
#  'INCOMING',
#  'INFORMATION',
#  'INDICATES',
#  'A',
#  'DEEPENING',
#  'OF',
#  'THE',
#  'HOUSING',
#  'CONTRACTION',
#  'A',
#  'WELL',
#  'A',
#  'SOME',
#  'SOFTENING',
#  'IN',
#  'LABOR',
#  'MARKET',
#  'THE',
#  'COMMITTEE',
#  'EXPECTS',
#  'INFLATION',
#  'TO',
#  'MODERATE',
#  'IN',
#  'COMING',
#  'QUARTER',
#  'BUT',
#  'IT',
#  'WILL',
#  'BE',
#  'NECESSARY',
#  'TO',
#  'CONTINUE',
#  'TO',
#  'MONITOR',
#  'INFLATION',
#  'DEVELOPMENT',
#  'CAREFULLY',
#  'APPRECIABLE',
#  'DOWNSIDE',
#  'RISK',
#  'TO',
#  'GROWTH',
#  'REMAIN',
#  'THE',
#  'COMMITTEE',
#  'WILL',
#  'CONTINUE',
#  'TO',
#  'ASS',
#  'THE',
#  'EFFECT',
#  'OF',
#  'FINANCIAL',
#  'AND',
#  'OTHER',
#  'DEVELOPMENT',
#  'ON',
#  'ECONOMIC',
#  'PROSPECT',
#  'AND',
#  'WILL',
#  'ACT',
#  'IN',
#  'A',
#  'TIMELY',
#  'MANNER',
#  'A',
#  'NEEDED',
#  'TO',
#  'ADDRESS',
#  'THOSE',
#  'RISK',
#  'VOTING',
#  'FOR',
#  'THE',
#  'FOMC',
#  'MONETARY',
#  'POLICY',
#  'ACTION',
#  'WERE',
#  'BEN',
#  'S',
#  'BERNANKE',
#  'CHAIRMAN',
#  'TIMOTHY',
#  'F',
#  'GEITHNER',
#  'VICE',
#  'CHAIRMAN',
#  'CHARLES',
#  'L',
#  'EVANS',
#  'THOMAS',
#  'M',
#  'HOENIG',
#  'DONALD',
#  'L',
#  'KOHN',
#  'RANDALL',
#  'S',
#  'KROSZNER',
#  'ERIC',
#  'S',
#  'ROSENGREN',
#  'AND',
#  'KEVIN',
#  'M',
#  'WARSH',
#  'VOTING',
#  'AGAINST',
#  'WA',
#  'WILLIAM',
#  'POOLE',
#  'WHO',
#  'DID',
#  'NOT',
#  'BELIEVE',
#  'THAT',
#  'CURRENT',
#  'CONDITION',
#  'JUSTIFIED',
#  'POLICY',
#  'ACTION',
#  'BEFORE',
#  'THE',
#  'REGULARLY',
#  'SCHEDULED',
#  'MEETING',
#  'NEXT',
#  'WEEK',
#  'ABSENT',
#  'AND',
#  'NOT',
#  'VOTING',
#  'WA',
#  'FREDERIC',
#  'S',
#  'MISHKIN',
#  'IN',
#  'A',
#  'RELATED',
#  'ACTION',
#  'THE',
#  'BOARD',
#  'OF',
#  'GOVERNORS',
#  'APPROVED',
#  'A',
#  '75-BASIS-POINT',
#  'DECREASE',
#  'IN',
#  'THE',
#  'DISCOUNT',
#  'RATE',
#  'TO',
#  '4',
#  'PERCENT',
#  'IN',
#  'TAKING',
#  'THIS',
#  'ACTION',
#  'THE',
#  'BOARD',
#  'APPROVED',
#  'THE',
#  'REQUEST',
#  'SUBMITTED',
#  'BY',
#  'THE',
#  'BOARDS',
#  'OF',
#  'DIRECTORS',
#  'OF',
#  'THE',
#  'FEDERAL',
#  'RESERVE',
#  'BANKS',
#  'OF',
#  'CHICAGO',
#  'AND',
#  'MINNEAPOLIS',
#  '20080122']

# %% [markdown]
# Code to read LM sentiment dictionary

# %%
fin_pos_words = pd.read_excel('LoughranMcDonald_SentimentWordLists_2018.xlsx',sheet_name='Positive',header=None)
fin_neg_words = pd.read_excel('LoughranMcDonald_SentimentWordLists_2018.xlsx',sheet_name='Negative',header=None)
fin_pos_words=fin_pos_words[0].values
fin_neg_words=fin_neg_words[0].values

# %%
fin_pos_words.head()
# Out:
# 0          ABLE
# 1     ABUNDANCE
# 2      ABUNDANT
# 3     ACCLAIMED
# 4    ACCOMPLISH
# Name: 0, dtype: object

# %%
fin_neg_words.head()
# Out:
# 0         ABANDON
# 1       ABANDONED
# 2      ABANDONING
# 3     ABANDONMENT
# 4    ABANDONMENTS
# Name: 0, dtype: object

# %% [markdown]
# Negation words defined in Loughran and Mcdonald

# %%
negate_words = ['NO', 'NOT', 'NONE', 'NEITHER', 'NEVER', 'NOBODY'] #From Loughran and Mcdonald (2011)

# %%
def check_negate(word):
    ''' Function checks whether word is a negation word'''
    if word in negate_words:
        return True
    else:
        return False

def sentiment_check(pos_words, neg_words, text):
    # method from Loughran and Mcdonald (2011)
    '''Function checks each word in the text that is passed in, will check if match
        in either positive or negative word list. 
        
        Text must be a list of strings
        Will also check for negation to negate/reverse positive words
        
        Returns: word count, pos count, neg count'''
    
    pos = 0
    neg = 0

    
    text = [word for word in text if len(word)>1]
    
    for i in range(len(text)):
        if text[i] in neg_words:
            neg+=1
            print(text[i],'neg')
        elif text[i] in pos_words:
            if i>=3:
                
                if check_negate(text[i-3]) or check_negate(text[i-2]) or check_negate(text[i-1]):
                    neg+=1
                    print(text[i],'neg')
                else:
                    pos+=1
                    print(text[i], 'pos')
            elif i==2:
                if check_negate(text[i-2]) or check_negate(text[i-1]):
                    neg+=1
                    print(text[i],'neg')
                else:
                    pos+=1
                    print(text[i], 'pos')

            elif i==1:
                if check_negate(text[i-1]):
                    neg+=1
                    print(text[i],'neg')
                else: 
                    pos+=1
                    print(text[i], 'pos')
            elif i==0:
                pos+=1
                print(text[i], 'pos')
    
    lista = [word for word in text if word not in stopwords.words('english')]
    #text = ' '.join(lista)
    text = [word for word in text if len(word)>1]
                                
    word_count = len(text)
                                
    return {'Pos Words':pos,'Neg Words':neg, 'Word Count': word_count}

# %%
len(word_list)
# Out:
# 253

# %%
path= './scraped_data/'
files = os.listdir(path)
polarity = []
subjectivity = []
for i in files:
    if i[-3:] =='csv':
        
        with open(path+i) as f:
            s = f.read()

            blob=TextBlob(s)
            #article = [word.lemmatize().upper() for word in blob.words]
            article = [word.upper() for word in blob.words]
            print(sentiment_check(fin_pos_words,fin_neg_words,article))
# Out:
# AGAINST neg
# LOSSES neg
# AGAINST neg
# LOSSES neg
# LOSSES neg
# {'Pos Words': 0, 'Neg Words': 5, 'Word Count': 0}
# ENHANCE pos
# ATTAINMENT pos
# STABILITY pos
# WEAKNESS neg
# ATTAINMENT pos
# STABILITY pos
# WEAKNESS neg
# ATTAINMENT pos
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 7, 'Neg Words': 3, 'Word Count': 0}
# CONCERNED neg
# IMBALANCES neg
# UNDERMINE neg
# AGAINST neg
# STABILITY pos
# CONCERNED neg
# IMBALANCES neg
# UNDERMINE neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 3, 'Neg Words': 9, 'Word Count': 0}
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# {'Pos Words': 3, 'Neg Words': 0, 'Word Count': 0}
# SUCCESSFUL pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CONCERNED neg
# IMBALANCES neg
# UNDERMINE neg
# AGAINST neg
# STABILITY pos
# CONCERNED neg
# IMBALANCES neg
# UNDERMINE neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 3, 'Neg Words': 9, 'Word Count': 0}
# MISTAKES neg
# LOST neg
# STOLEN neg
# MISTAKES neg
# LOST neg
# STOLEN neg
# {'Pos Words': 0, 'Neg Words': 6, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# COUNTERFEITING neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# STRENGTH pos
# STABILITY pos
# STRENGTH pos
# DEPENDABILITY pos
# INTEGRITY pos
# SUCCESSFUL pos
# COUNTERFEITERS neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# EFFECTIVE pos
# PENALTY neg
# COUNTERFEITING neg
# EFFECTIVE pos
# INCIDENCE neg
# COUNTERFEITING neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# EFFICIENTLY pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# STRENGTH pos
# STABILITY pos
# STRENGTH pos
# DEPENDABILITY pos
# INTEGRITY pos
# SUCCESSFUL pos
# COUNTERFEITERS neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# EFFECTIVE pos
# PENALTY neg
# COUNTERFEITING neg
# EFFECTIVE pos
# INCIDENCE neg
# COUNTERFEITING neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# EFFICIENTLY pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# COUNTERFEITING neg
# STRENGTH pos
# STABILITY pos
# STRENGTH pos
# DEPENDABILITY pos
# INTEGRITY pos
# SUCCESSFUL pos
# COUNTERFEITERS neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# EFFECTIVE pos
# PENALTY neg
# COUNTERFEITING neg
# EFFECTIVE pos
# INCIDENCE neg
# COUNTERFEITING neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# EFFICIENTLY pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# STRENGTH pos
# DEPENDABILITY pos
# INTEGRITY pos
# SUCCESSFUL pos
# COUNTERFEITERS neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# EFFECTIVE pos
# PENALTY neg
# COUNTERFEITING neg
# EFFECTIVE pos
# INCIDENCE neg
# COUNTERFEITING neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# EFFICIENTLY pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# COUNTERFEITING neg
# EFFECTIVE pos
# PENALTY neg
# COUNTERFEITING neg
# EFFECTIVE pos
# INCIDENCE neg
# COUNTERFEITING neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# EFFICIENTLY pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# EFFECTIVE pos
# INCIDENCE neg
# COUNTERFEITING neg
# COUNTERFEIT neg
# COUNTERFEITING neg
# COUNTERFEITING neg
# EFFICIENTLY pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# COUNTERFEITING neg
# EFFICIENTLY pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# INNOVATIVE pos
# ENHANCEMENTS pos
# ENHANCED pos
# COUNTERFEIT neg
# {'Pos Words': 67, 'Neg Words': 76, 'Word Count': 0}
# GAINS pos
# CONCERNED neg
# DISPARITY neg
# IMBALANCES neg
# UNDERMINE neg
# STABILITY pos
# GAINS pos
# CONCERNED neg
# DISPARITY neg
# IMBALANCES neg
# UNDERMINE neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 5, 'Neg Words': 9, 'Word Count': 0}
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# {'Pos Words': 3, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# SUSPICIOUS neg
# CRIMES neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# EASIER pos
# EASIER pos
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# CORRECTED neg
# VALUABLE pos
# ABLE pos
# QUESTIONS neg
# CRIMES neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# EASIER pos
# EASIER pos
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# CORRECTED neg
# VALUABLE pos
# ABLE pos
# QUESTIONS neg
# SUSPICIOUS neg
# EASIER pos
# EASIER pos
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# CORRECTED neg
# VALUABLE pos
# ABLE pos
# QUESTIONS neg
# EASIER pos
# EASIER pos
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# INTRUSION neg
# SUSPICIOUS neg
# SUSPICIOUS neg
# CORRECTED neg
# VALUABLE pos
# ABLE pos
# QUESTIONS neg
# VALUABLE pos
# ABLE pos
# QUESTIONS neg
# ABLE pos
# QUESTIONS neg
# ABLE pos
# QUESTIONS neg
# QUESTIONS neg
# {'Pos Words': 20, 'Neg Words': 44, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# AGAINST neg
# THREATS neg
# HAZARDS neg
# INTEGRITY pos
# AGAINST neg
# UNAUTHORIZED neg
# HARM neg
# INCONVENIENCE neg
# THREATEN neg
# THREATS neg
# UNAUTHORIZED neg
# INTRUSION neg
# EFFECTIVE pos
# AGAINST neg
# THREATS neg
# HAZARDS neg
# INTEGRITY pos
# AGAINST neg
# UNAUTHORIZED neg
# HARM neg
# INCONVENIENCE neg
# THREATEN neg
# THREATS neg
# UNAUTHORIZED neg
# INTRUSION neg
# EFFECTIVE pos
# AGAINST neg
# THREATS neg
# HAZARDS neg
# INTEGRITY pos
# AGAINST neg
# UNAUTHORIZED neg
# HARM neg
# INCONVENIENCE neg
# THREATEN neg
# THREATS neg
# UNAUTHORIZED neg
# INTRUSION neg
# EFFECTIVE pos
# AGAINST neg
# THREATS neg
# HAZARDS neg
# INTEGRITY pos
# AGAINST neg
# UNAUTHORIZED neg
# HARM neg
# INCONVENIENCE neg
# THREATEN neg
# THREATS neg
# UNAUTHORIZED neg
# INTRUSION neg
# EFFECTIVE pos
# THREATEN neg
# THREATS neg
# UNAUTHORIZED neg
# INTRUSION neg
# EFFECTIVE pos
# UNAUTHORIZED neg
# INTRUSION neg
# EFFECTIVE pos
# INTRUSION neg
# EFFECTIVE pos
# EFFECTIVE pos
# {'Pos Words': 12, 'Neg Words': 51, 'Word Count': 0}
# PROFITABLE pos
# STRONG pos
# CRITICAL neg
# GAINS pos
# LOSSES neg
# PROFITABLE pos
# STRONG pos
# CRITICAL neg
# GAINS pos
# LOSSES neg
# PROFITABLE pos
# STRONG pos
# CRITICAL neg
# GAINS pos
# LOSSES neg
# STRONG pos
# CRITICAL neg
# GAINS pos
# LOSSES neg
# GAINS pos
# LOSSES neg
# {'Pos Words': 12, 'Neg Words': 9, 'Word Count': 0}
# ADVANCES pos
# AGAINST neg
# STABILITY pos
# ADVANCES pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 6, 'Neg Words': 4, 'Word Count': 0}
# QUESTIONS neg
# {'Pos Words': 0, 'Neg Words': 1, 'Word Count': 0}
# THREATEN neg
# EFFECTIVE pos
# STRONG pos
# ENHANCED pos
# EXCESSIVE neg
# BURDEN neg
# THREATEN neg
# EFFECTIVE pos
# STRONG pos
# ENHANCED pos
# EXCESSIVE neg
# BURDEN neg
# EFFECTIVE pos
# STRONG pos
# ENHANCED pos
# EXCESSIVE neg
# BURDEN neg
# EFFECTIVE pos
# STRONG pos
# ENHANCED pos
# EXCESSIVE neg
# BURDEN neg
# {'Pos Words': 12, 'Neg Words': 10, 'Word Count': 0}
# ADVANCES pos
# CONCERNED neg
# STABILITY pos
# ADVANCES pos
# CONCERNED neg
# STABILITY pos
# CONCERNED neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 6, 'Neg Words': 4, 'Word Count': 0}
# POPULAR pos
# POPULAR pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# BARRIERS neg
# BARRIERS neg
# {'Pos Words': 0, 'Neg Words': 2, 'Word Count': 0}
# STRESSES neg
# STRENGTHEN pos
# STRENGTHEN pos
# {'Pos Words': 2, 'Neg Words': 1, 'Word Count': 0}
# ENCOURAGES pos
# ENCOURAGES pos
# STRENGTHEN pos
# BEST pos
# ENCOURAGES pos
# STRENGTHEN pos
# STRENGTHEN pos
# STRENGTHEN pos
# {'Pos Words': 8, 'Neg Words': 0, 'Word Count': 0}
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# ADVANTAGE pos
# {'Pos Words': 17, 'Neg Words': 0, 'Word Count': 0}
# PREDATORY neg
# PREDATORY neg
# PREDATORY neg
# {'Pos Words': 0, 'Neg Words': 3, 'Word Count': 0}
# ENHANCED pos
# ADVANCES pos
# POSES neg
# CONDUCIVE pos
# AGAINST neg
# STABILITY pos
# ENHANCED pos
# ADVANCES pos
# POSES neg
# CONDUCIVE pos
# AGAINST neg
# STABILITY pos
# POSES neg
# CONDUCIVE pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 11, 'Neg Words': 7, 'Word Count': 0}
# ADVERSELY neg
# ADVERSELY neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# {'Pos Words': 11, 'Neg Words': 107, 'Word Count': 0}
# TIGHTENING neg
# EASING neg
# AGAINST neg
# STABILITY pos
# TIGHTENING neg
# EASING neg
# AGAINST neg
# STABILITY pos
# EASING neg
# AGAINST neg
# STABILITY pos
# {'Pos Words': 3, 'Neg Words': 8, 'Word Count': 0}
# ADVERSELY neg
# ADVERSELY neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# EFFICIENT pos
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# DEFAULT neg
# CONCERNS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# ADVERSELY neg
# PROBLEM neg
# DETERIORATION neg
# HIGHEST pos
# PROBLEM neg
# PROBLEMS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# WEAKNESS neg
# SERIOUS neg
# ADVERSE neg
# SUBSTANDARD neg
# DOUBTFUL neg
# LOSS neg
# {'Pos Words': 11, 'Neg Words': 107, 'Word Count': 0}
# VIOLATIONS neg
# VIOLATIONS neg
# VIOLATIONS neg
# WRONG neg
# VIOLATIONS neg
# PROBLEM neg
# INVESTIGATION neg
# VIOLATIONS neg
# VIOLATIONS neg
# WRONG neg
# VIOLATIONS neg
# PROBLEM neg
# INVESTIGATION neg
# VIOLATIONS neg
# VIOLATIONS neg
# WRONG neg
# VIOLATIONS neg
# PROBLEM neg
# INVESTIGATION neg
# VIOLATIONS neg
# VIOLATIONS neg
# {'Pos Words': 0, 'Neg Words': 21, 'Word Count': 0}
# CONVICTIONS neg
# DEVIATED neg
# INTEGRITY pos
# CONVICTIONS neg
# DEVIATED neg
# INTEGRITY pos
# {'Pos Words': 2, 'Neg Words': 4, 'Word Count': 0}
# DRAG neg
# ERODING neg
# SHORTFALLS neg
# STRESS neg
# SLOWING neg
# PERSIST neg
# DIMINISHED neg
# ABSENCE neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# DRAG neg
# ERODING neg
# SHORTFALLS neg
# STRESS neg
# SLOWING neg
# PERSIST neg
# DIMINISHED neg
# ABSENCE neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 3, 'Neg Words': 22, 'Word Count': 0}
# BENEFITED pos
# MISSED neg
# PLEASURE pos
# GOOD pos
# BENEFITED pos
# MISSED neg
# PLEASURE pos
# GOOD pos
# {'Pos Words': 6, 'Neg Words': 2, 'Word Count': 0}
# WEAKENING neg
# ADVANCES pos
# GAINS pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# WEAKENING neg
# ADVANCES pos
# GAINS pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# WEAKENING neg
# ADVANCES pos
# GAINS pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 10, 'Neg Words': 11, 'Word Count': 0}
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# {'Pos Words': 6, 'Neg Words': 0, 'Word Count': 0}
# ENHANCED pos
# DISCLOSED neg
# DISCLOSED neg
# IMPROVED pos
# DISCLOSED neg
# INNOVATIONS pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# ENHANCED pos
# DISCLOSED neg
# DISCLOSED neg
# IMPROVED pos
# DISCLOSED neg
# INNOVATIONS pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# DISCLOSED neg
# DISCLOSED neg
# IMPROVED pos
# DISCLOSED neg
# INNOVATIONS pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# DISCLOSED neg
# INNOVATIONS pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# DISCLOSED neg
# INNOVATIONS pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# INNOVATIONS pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# ENCOURAGES pos
# ENHANCED pos
# {'Pos Words': 36, 'Neg Words': 11, 'Word Count': 0}
# EFFECTIVE pos
# LIMITATIONS neg
# EFFECTIVE pos
# LIMITATIONS neg
# EFFECTIVE pos
# LIMITATIONS neg
# {'Pos Words': 3, 'Neg Words': 3, 'Word Count': 0}
# QUESTIONS neg
# QUESTIONS neg
# QUESTIONS neg
# QUESTIONS neg
# QUESTIONS neg
# QUESTIONS neg
# QUESTIONS neg
# QUESTIONS neg
# {'Pos Words': 0, 'Neg Words': 8, 'Word Count': 0}
# AGAINST neg
# LOSSES neg
# AGAINST neg
# LOSSES neg
# AGAINST neg
# LOSSES neg
# LOSSES neg
# {'Pos Words': 0, 'Neg Words': 7, 'Word Count': 0}
# ERODED neg
# EXACERBATED neg
# WEAKENED neg
# CUT neg
# SHARPLY neg
# ADVANCES pos
# GAINS pos
# GAINS pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# ERODED neg
# EXACERBATED neg
# WEAKENED neg
# CUT neg
# SHARPLY neg
# ADVANCES pos
# GAINS pos
# GAINS pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# ADVANCES pos
# GAINS pos
# GAINS pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 13, 'Neg Words': 18, 'Word Count': 0}
# BENEFITING pos
# BENEFITING pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# FORCE neg
# BEST pos
# FORCE neg
# POPULAR pos
# BEST pos
# FAVORABLE pos
# BEST pos
# QUESTIONS neg
# BEST pos
# CLOSING neg
# QUESTIONS neg
# UNFAIR neg
# PROBLEMS neg
# BEST pos
# BEST pos
# FORCE neg
# IMPAIRED neg
# FORCE neg
# POPULAR pos
# BEST pos
# FAVORABLE pos
# BEST pos
# QUESTIONS neg
# BEST pos
# CLOSING neg
# QUESTIONS neg
# UNFAIR neg
# PROBLEMS neg
# BEST pos
# BEST pos
# FORCE neg
# IMPAIRED neg
# QUESTIONS neg
# BEST pos
# CLOSING neg
# QUESTIONS neg
# UNFAIR neg
# PROBLEMS neg
# BEST pos
# BEST pos
# FORCE neg
# IMPAIRED neg
# UNFAIR neg
# PROBLEMS neg
# BEST pos
# BEST pos
# FORCE neg
# IMPAIRED neg
# FORCE neg
# IMPAIRED neg
# IMPAIRED neg
# IMPAIRED neg
# IMPAIRED neg
# IMPAIRED neg
# IMPAIRED neg
# IMPAIRED neg
# IMPAIRED neg
# {'Pos Words': 20, 'Neg Words': 37, 'Word Count': 0}
# DECLINES neg
# DIMINISHED neg
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# PERSISTENT neg
# DECLINES neg
# DIMINISHED neg
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# DIMINISHED neg
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 4, 'Neg Words': 17, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# ENCOURAGES pos
# ENHANCE pos
# ENHANCE pos
# DISCLOSED neg
# ENHANCED pos
# ENHANCE pos
# TRANSPARENCY pos
# ENHANCE pos
# DISCLOSED neg
# ENHANCED pos
# ENHANCE pos
# TRANSPARENCY pos
# ENHANCE pos
# TRANSPARENCY pos
# {'Pos Words': 12, 'Neg Words': 2, 'Word Count': 0}
# DECLINED neg
# IMPROVE pos
# INCONSISTENCIES neg
# TRANSPARENCY pos
# LOSSES neg
# DECLINED neg
# IMPROVE pos
# INCONSISTENCIES neg
# TRANSPARENCY pos
# LOSSES neg
# DECLINED neg
# IMPROVE pos
# INCONSISTENCIES neg
# TRANSPARENCY pos
# LOSSES neg
# DECLINED neg
# IMPROVE pos
# INCONSISTENCIES neg
# TRANSPARENCY pos
# LOSSES neg
# TRANSPARENCY pos
# LOSSES neg
# {'Pos Words': 9, 'Neg Words': 13, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DETERIORATION neg
# STRENGTHENED pos
# DIMINISHED neg
# UNEXPECTED neg
# CHALLENGES neg
# BETTER pos
# VOLATILITY neg
# STRESSES neg
# STRESS neg
# DETERIORATION neg
# STRENGTHENED pos
# DIMINISHED neg
# UNEXPECTED neg
# CHALLENGES neg
# BETTER pos
# VOLATILITY neg
# STRESSES neg
# STRESS neg
# DETERIORATION neg
# STRENGTHENED pos
# DIMINISHED neg
# UNEXPECTED neg
# CHALLENGES neg
# BETTER pos
# VOLATILITY neg
# STRESSES neg
# STRESS neg
# DETERIORATION neg
# STRENGTHENED pos
# DIMINISHED neg
# UNEXPECTED neg
# CHALLENGES neg
# BETTER pos
# VOLATILITY neg
# STRESSES neg
# STRESS neg
# DIMINISHED neg
# UNEXPECTED neg
# CHALLENGES neg
# BETTER pos
# VOLATILITY neg
# STRESSES neg
# STRESS neg
# BETTER pos
# VOLATILITY neg
# STRESSES neg
# STRESS neg
# VOLATILITY neg
# STRESSES neg
# STRESS neg
# {'Pos Words': 10, 'Neg Words': 40, 'Word Count': 0}
# WEAKENED neg
# IMPRESSIVE pos
# PERSISTENT neg
# EROSION neg
# PROFITABILITY pos
# DAMPEN neg
# SLOWER neg
# THREATENS neg
# UNACCEPTABLY neg
# WEAK neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# WEAKENED neg
# IMPRESSIVE pos
# PERSISTENT neg
# EROSION neg
# PROFITABILITY pos
# DAMPEN neg
# SLOWER neg
# THREATENS neg
# UNACCEPTABLY neg
# WEAK neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# PERSISTENT neg
# EROSION neg
# PROFITABILITY pos
# DAMPEN neg
# SLOWER neg
# THREATENS neg
# UNACCEPTABLY neg
# WEAK neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 9, 'Neg Words': 31, 'Word Count': 0}
# AGAINST neg
# PREVENTING neg
# FRAUDULENT neg
# GAIN pos
# SUSPICIOUS neg
# UNAUTHORIZED neg
# DETER neg
# FRAUDULENT neg
# PREVENTING neg
# FRAUDULENT neg
# GAIN pos
# SUSPICIOUS neg
# UNAUTHORIZED neg
# DETER neg
# FRAUDULENT neg
# SUSPICIOUS neg
# UNAUTHORIZED neg
# DETER neg
# FRAUDULENT neg
# UNAUTHORIZED neg
# DETER neg
# FRAUDULENT neg
# {'Pos Words': 2, 'Neg Words': 20, 'Word Count': 0}
# WARN neg
# EXCESSIVE neg
# WEAKEN neg
# ENABLE pos
# EASILY pos
# EXCLUSIVELY pos
# STABLE pos
# INADEQUATE neg
# WARN neg
# EXCESSIVE neg
# WEAKEN neg
# ENABLE pos
# EASILY pos
# EXCLUSIVELY pos
# STABLE pos
# INADEQUATE neg
# ENABLE pos
# EASILY pos
# EXCLUSIVELY pos
# STABLE pos
# INADEQUATE neg
# INADEQUATE neg
# INADEQUATE neg
# {'Pos Words': 12, 'Neg Words': 11, 'Word Count': 0}
# EASILY pos
# UNLAWFULLY neg
# VICTIMS neg
# VALUABLE pos
# FRAUD neg
# FORCE neg
# AGAINST neg
# FRAUD neg
# FORCE neg
# AGAINST neg
# AGAINST neg
# AGAINST neg
# AGAINST neg
# AGAINST neg
# {'Pos Words': 2, 'Neg Words': 12, 'Word Count': 0}
# DECLINE neg
# EROSION neg
# PROFITABILITY pos
# SLOWER neg
# EASING neg
# IMPRESSIVE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# DECLINE neg
# EROSION neg
# PROFITABILITY pos
# SLOWER neg
# EASING neg
# IMPRESSIVE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# DECLINE neg
# EROSION neg
# PROFITABILITY pos
# SLOWER neg
# EASING neg
# IMPRESSIVE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# EASING neg
# IMPRESSIVE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 12, 'Neg Words': 23, 'Word Count': 0}
# GOOD pos
# QUESTION neg
# QUESTION neg
# GOOD pos
# QUESTION neg
# QUESTION neg
# GOOD pos
# QUESTION neg
# QUESTION neg
# GOOD pos
# QUESTION neg
# QUESTION neg
# QUESTION neg
# QUESTION neg
# {'Pos Words': 4, 'Neg Words': 10, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# RESIGN neg
# RESIGNATION neg
# REWARDING pos
# RESIGN neg
# GREAT pos
# ACCOMPLISH pos
# SMOOTH pos
# REWARDING pos
# RESIGN neg
# GREAT pos
# ACCOMPLISH pos
# SMOOTH pos
# GREAT pos
# ACCOMPLISH pos
# SMOOTH pos
# {'Pos Words': 11, 'Neg Words': 4, 'Word Count': 0}
# EFFECTIVE pos
# RELINQUISHING neg
# RELINQUISHING neg
# {'Pos Words': 1, 'Neg Words': 2, 'Word Count': 0}
# DECLINE neg
# DECLINING neg
# PROFITABILITY pos
# WEAK neg
# SLOWING neg
# EASING neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# DECLINING neg
# PROFITABILITY pos
# WEAK neg
# SLOWING neg
# EASING neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 8, 'Neg Words': 15, 'Word Count': 0}
# EFFICIENCY pos
# FAILS neg
# VIOLATION neg
# EFFICIENCY pos
# FAILS neg
# VIOLATION neg
# FAILS neg
# VIOLATION neg
# FAILS neg
# VIOLATION neg
# FAILS neg
# VIOLATION neg
# FAILS neg
# VIOLATION neg
# {'Pos Words': 2, 'Neg Words': 12, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# COMPLAINT neg
# COMPLAINTS neg
# INVESTIGATES neg
# INVESTIGATION neg
# COMPLAINTS neg
# INVESTIGATES neg
# INVESTIGATION neg
# {'Pos Words': 0, 'Neg Words': 7, 'Word Count': 0}
# DECLINE neg
# WEAKEN neg
# SLOWING neg
# EASING neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# WEAKEN neg
# SLOWING neg
# EASING neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 6, 'Neg Words': 13, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DISTURBANCES neg
# DISTURBANCES neg
# DISTURBANCES neg
# DISTURBANCES neg
# DISTURBANCES neg
# DISTURBANCES neg
# {'Pos Words': 0, 'Neg Words': 6, 'Word Count': 0}
# ABLE pos
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# TRAGIC neg
# WEAK neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# TRAGIC neg
# WEAK neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 4, 'Neg Words': 6, 'Word Count': 0}
# SUCCESSFUL pos
# OPPORTUNITY pos
# DISCLOSING neg
# ENCOURAGED pos
# OPPORTUNITY pos
# DISCLOSING neg
# ENCOURAGED pos
# ENCOURAGED pos
# ENCOURAGED pos
# {'Pos Words': 7, 'Neg Words': 2, 'Word Count': 0}
# BETTER pos
# IMPROVE pos
# VALUABLE pos
# EASY pos
# BETTER pos
# IMPROVE pos
# VALUABLE pos
# EASY pos
# EASY pos
# EASY pos
# {'Pos Words': 10, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# WEAK neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# WEAK neg
# FAVORABLE pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 5, 'Neg Words': 8, 'Word Count': 0}
# DETERIORATION neg
# ADVERSELY neg
# ADVERSELY neg
# DIFFICULTY neg
# DETERIORATION neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# ADVERSELY neg
# ADVERSELY neg
# DIFFICULTY neg
# DETERIORATION neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# ADVERSELY neg
# ADVERSELY neg
# DIFFICULTY neg
# DETERIORATION neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# DETERIORATION neg
# DIFFICULTY neg
# DETERIORATION neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# WEAKENING neg
# GREATER pos
# PROBLEMS neg
# WEAKNESS neg
# LITIGATION neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# PROBLEMS neg
# ADVERSELY neg
# STRONG pos
# DIFFICULTY neg
# VULNERABLE neg
# DETERIORATION neg
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# DESPITE pos
# DETERIORATION neg
# IMPROVEMENT pos
# IMPROVEMENT pos
# ADVERSELY neg
# ADVERSELY neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# DETERIORATION neg
# STRONG pos
# CONCERNS neg
# DETERIORATION neg
# LOSS neg
# {'Pos Words': 49, 'Neg Words': 167, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CONCERNS neg
# DETERIORATION neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# ENHANCE pos
# ADVANCES pos
# FAVORABLE pos
# CONCERNS neg
# DETERIORATION neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# ENHANCE pos
# ADVANCES pos
# FAVORABLE pos
# ENHANCE pos
# ADVANCES pos
# FAVORABLE pos
# {'Pos Words': 11, 'Neg Words': 8, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFICIENT pos
# DECLINED neg
# GAIN pos
# BETTER pos
# STRONG pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# EFFICIENT pos
# DECLINED neg
# GAIN pos
# BETTER pos
# STRONG pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINED neg
# GAIN pos
# BETTER pos
# STRONG pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# GAIN pos
# BETTER pos
# STRONG pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# GAIN pos
# BETTER pos
# STRONG pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# DECLINING neg
# BETTER pos
# STRONG pos
# ENABLE pos
# ENABLE pos
# {'Pos Words': 54, 'Neg Words': 15, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSED neg
# POSITIVE pos
# LATE neg
# INVESTIGATION neg
# POSTPONE neg
# INVESTIGATION neg
# POSTPONE neg
# INVESTIGATION neg
# POSTPONE neg
# INVESTIGATION neg
# POSTPONE neg
# {'Pos Words': 1, 'Neg Words': 10, 'Word Count': 0}
# RESIGNATION neg
# RESIGNATION neg
# RESIGNATION neg
# RESIGNATION neg
# {'Pos Words': 0, 'Neg Words': 4, 'Word Count': 0}
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# ENHANCE pos
# ADVANCES pos
# FAVORABLE pos
# WEAKNESS neg
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# ENHANCE pos
# ADVANCES pos
# FAVORABLE pos
# ENHANCE pos
# ADVANCES pos
# FAVORABLE pos
# {'Pos Words': 11, 'Neg Words': 6, 'Word Count': 0}
# RESIGNATION neg
# EFFECTIVE pos
# RESIGNATION neg
# IMPENDING neg
# GREATER pos
# INTEGRITY pos
# RESIGNING neg
# SMOOTH pos
# RESIGNATION neg
# IMPENDING neg
# GREATER pos
# INTEGRITY pos
# RESIGNING neg
# SMOOTH pos
# GREATER pos
# INTEGRITY pos
# RESIGNING neg
# SMOOTH pos
# RESIGNING neg
# SMOOTH pos
# SMOOTH pos
# {'Pos Words': 12, 'Neg Words': 9, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# RESIGNATION neg
# RESIGNATION neg
# RESIGNATION neg
# RESIGNATION neg
# RESIGNATION neg
# {'Pos Words': 0, 'Neg Words': 5, 'Word Count': 0}
# AGAINST neg
# LOSSES neg
# AGAINST neg
# LOSSES neg
# AGAINST neg
# LOSSES neg
# LOSSES neg
# {'Pos Words': 0, 'Neg Words': 7, 'Word Count': 0}
# RESIGNATION neg
# EFFECTIVE pos
# ACCOMPLISH pos
# ABLE pos
# IMPENDING neg
# DIFFICULT neg
# ENHANCED pos
# LEADING pos
# ACCOMPLISH pos
# ABLE pos
# IMPENDING neg
# DIFFICULT neg
# ENHANCED pos
# LEADING pos
# ACCOMPLISH pos
# ABLE pos
# IMPENDING neg
# DIFFICULT neg
# ENHANCED pos
# LEADING pos
# IMPENDING neg
# DIFFICULT neg
# ENHANCED pos
# LEADING pos
# DIFFICULT neg
# ENHANCED pos
# LEADING pos
# LEADING pos
# LEADING pos
# {'Pos Words': 19, 'Neg Words': 10, 'Word Count': 0}
# WEAKNESS neg
# DIMINISH neg
# FAVORABLE pos
# STRENGTH pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# WEAKNESS neg
# DIMINISH neg
# FAVORABLE pos
# STRENGTH pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# STRENGTH pos
# AGAINST neg
# STABILITY pos
# WEAKNESS neg
# {'Pos Words': 8, 'Neg Words': 10, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# OPPORTUNITY pos
# OPPORTUNITY pos
# OPPORTUNITY pos
# {'Pos Words': 3, 'Neg Words': 0, 'Word Count': 0}
# OPPORTUNITY pos
# OPPORTUNITY pos
# OPPORTUNITY pos
# {'Pos Words': 3, 'Neg Words': 0, 'Word Count': 0}
# OPPORTUNITY pos
# OPPORTUNITY pos
# OPPORTUNITY pos
# OPPORTUNITY pos
# {'Pos Words': 4, 'Neg Words': 0, 'Word Count': 0}
# IMPROVE pos
# EFFICIENCY pos
# COSTLY neg
# IMPROVED pos
# IMPROVE pos
# EFFICIENCY pos
# BURDEN neg
# {'Pos Words': 5, 'Neg Words': 2, 'Word Count': 0}
# BOLSTERED pos
# STRENGTHENING pos
# AGAINST neg
# STABILITY pos
# DISSENTERS neg
# LAG neg
# BOLSTERED pos
# STRENGTHENING pos
# AGAINST neg
# STABILITY pos
# DISSENTERS neg
# LAG neg
# AGAINST neg
# STABILITY pos
# DISSENTERS neg
# LAG neg
# DISSENTERS neg
# LAG neg
# {'Pos Words': 7, 'Neg Words': 11, 'Word Count': 0}
# BETTER pos
# PROBLEMS neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHENING pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STRENGTHENING pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# AGAINST neg
# AGAINST neg
# {'Pos Words': 5, 'Neg Words': 8, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHENING pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STRENGTHENING pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# AGAINST neg
# AGAINST neg
# {'Pos Words': 5, 'Neg Words': 8, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# PROLONGED neg
# WEAKNESS neg
# PROBLEMS neg
# IMPROVING pos
# AGAINST neg
# STABILITY pos
# PROLONGED neg
# WEAKNESS neg
# PROBLEMS neg
# IMPROVING pos
# AGAINST neg
# STABILITY pos
# IMPROVING pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 7, 'Neg Words': 10, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVING pos
# PERSISTS neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# IMPROVING pos
# PERSISTS neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# IMPROVING pos
# PERSISTS neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# AGAINST neg
# AGAINST neg
# {'Pos Words': 7, 'Neg Words': 13, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# GREATER pos
# EASING neg
# AGAINST neg
# STABILITY pos
# GREATER pos
# EASING neg
# AGAINST neg
# STABILITY pos
# EASING neg
# AGAINST neg
# STABILITY pos
# {'Pos Words': 5, 'Neg Words': 6, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# INCONSISTENT neg
# AGAINST neg
# STABILITY pos
# INCONSISTENT neg
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 3, 'Neg Words': 5, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# DISCONTINUED neg
# DISCONTINUED neg
# {'Pos Words': 1, 'Neg Words': 2, 'Word Count': 0}
# IMPROVING pos
# AGAINST neg
# STABILITY pos
# IMPROVING pos
# AGAINST neg
# STABILITY pos
# AGAINST neg
# STABILITY pos
# {'Pos Words': 5, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DISAPPOINTING neg
# IMPROVING pos
# STABILITY pos
# DISAPPOINTING neg
# IMPROVING pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 5, 'Neg Words': 2, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DISAPPOINTING neg
# BOLSTERED pos
# STRENGTHENED pos
# IMPROVING pos
# IMPROVEMENT pos
# ATTAINMENT pos
# UNWELCOME neg
# ACHIEVING pos
# WEAKNESS neg
# DISAPPOINTING neg
# BOLSTERED pos
# STRENGTHENED pos
# IMPROVING pos
# IMPROVEMENT pos
# ATTAINMENT pos
# UNWELCOME neg
# ACHIEVING pos
# WEAKNESS neg
# IMPROVEMENT pos
# ATTAINMENT pos
# UNWELCOME neg
# ACHIEVING pos
# WEAKNESS neg
# {'Pos Words': 15, 'Neg Words': 8, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# STABILIZING pos
# IMPROVE pos
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# AGAINST neg
# IMPROVED pos
# STABILIZING pos
# IMPROVE pos
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# AGAINST neg
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# AGAINST neg
# AGAINST neg
# AGAINST neg
# {'Pos Words': 9, 'Neg Words': 11, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# {'Pos Words': 2, 'Neg Words': 4, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# WEAKENING neg
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# WEAKENING neg
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# {'Pos Words': 3, 'Neg Words': 8, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STABILIZING pos
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# STABILIZING pos
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# ATTAINMENT pos
# UNWELCOME neg
# CONCERN neg
# {'Pos Words': 5, 'Neg Words': 6, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVING pos
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# IMPROVING pos
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# {'Pos Words': 5, 'Neg Words': 6, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVEMENT pos
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# IMPROVEMENT pos
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# {'Pos Words': 5, 'Neg Words': 6, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# LOSSES neg
# SLOWED neg
# LAGGED neg
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# LOSSES neg
# SLOWED neg
# LAGGED neg
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# ATTAINMENT pos
# UNWELCOME neg
# DIMINISHED neg
# {'Pos Words': 3, 'Neg Words': 12, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# ATTAINMENT pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# {'Pos Words': 6, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# IMPROVED pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 11, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVEMENT pos
# SLOWED neg
# STRONGER pos
# ATTAINMENT pos
# STABILITY pos
# IMPROVEMENT pos
# SLOWED neg
# STRONGER pos
# ATTAINMENT pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# {'Pos Words': 10, 'Neg Words': 2, 'Word Count': 0}
# REGAINED pos
# IMPROVED pos
# DESPITE pos
# ATTAINMENT pos
# STABILITY pos
# REGAINED pos
# IMPROVED pos
# DESPITE pos
# ATTAINMENT pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# {'Pos Words': 12, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# IMPROVED pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 5, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 28, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 28, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 20, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# {'Pos Words': 6, 'Neg Words': 0, 'Word Count': 0}
# SLOWED neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# SLOWED neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# SLOWED neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# SLOWED neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 16, 'Neg Words': 4, 'Word Count': 0}
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 16, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DESPITE pos
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 20, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# STRENGTHENED pos
# LATE neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# DESPITE pos
# STRENGTHENED pos
# LATE neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# DESPITE pos
# STRENGTHENED pos
# LATE neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# DESPITE pos
# STRENGTHENED pos
# LATE neg
# IMPROVE pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 21, 'Neg Words': 4, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# GOOD pos
# TRAGIC neg
# DEVASTATION neg
# BOOST pos
# DISRUPTION neg
# UNFORTUNATE neg
# PERSISTENT neg
# THREAT neg
# ATTAINMENT pos
# STABILITY pos
# AGAINST neg
# GOOD pos
# TRAGIC neg
# DEVASTATION neg
# BOOST pos
# DISRUPTION neg
# UNFORTUNATE neg
# PERSISTENT neg
# THREAT neg
# ATTAINMENT pos
# STABILITY pos
# AGAINST neg
# GOOD pos
# TRAGIC neg
# DEVASTATION neg
# BOOST pos
# DISRUPTION neg
# UNFORTUNATE neg
# PERSISTENT neg
# THREAT neg
# ATTAINMENT pos
# STABILITY pos
# AGAINST neg
# GOOD pos
# TRAGIC neg
# DEVASTATION neg
# BOOST pos
# DISRUPTION neg
# VOLATILITY neg
# UNFORTUNATE neg
# PERSISTENT neg
# THREAT neg
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# AGAINST neg
# {'Pos Words': 17, 'Neg Words': 29, 'Word Count': 0}
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# EFFECTIVE pos
# {'Pos Words': 4, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DISRUPTIONS neg
# DEPRESSED neg
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DISRUPTIONS neg
# DEPRESSED neg
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DISRUPTIONS neg
# DEPRESSED neg
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# DISRUPTIONS neg
# DEPRESSED neg
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# ATTAINMENT pos
# STABILITY pos
# STABILITY pos
# {'Pos Words': 15, 'Neg Words': 8, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DISRUPTIONS neg
# ATTAINMENT pos
# STABILITY pos
# DISRUPTIONS neg
# ATTAINMENT pos
# STABILITY pos
# DESPITE pos
# DISRUPTIONS neg
# ATTAINMENT pos
# STABILITY pos
# {'Pos Words': 7, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# ATTAINMENT pos
# STABILITY pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# SLOWING neg
# REBOUNDED pos
# GAINS pos
# ATTAINMENT pos
# STABILITY pos
# {'Pos Words': 4, 'Neg Words': 1, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRONG pos
# LAGGED neg
# GAINS pos
# ATTAINMENT pos
# {'Pos Words': 3, 'Neg Words': 1, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRONG pos
# LAGGED neg
# GAINS pos
# ATTAINMENT pos
# {'Pos Words': 3, 'Neg Words': 1, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRONG pos
# LAGGED neg
# AGAINST neg
# {'Pos Words': 1, 'Neg Words': 2, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# AGAINST neg
# {'Pos Words': 0, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# SLOWED neg
# AGAINST neg
# {'Pos Words': 0, 'Neg Words': 2, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# SLOWED neg
# AGAINST neg
# {'Pos Words': 0, 'Neg Words': 2, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STABILIZATION pos
# IMPROVED pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CONCERN neg
# FAIL neg
# {'Pos Words': 0, 'Neg Words': 2, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# SLOWED neg
# CONCERN neg
# FAIL neg
# {'Pos Words': 0, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# IMPROVED pos
# CONCERN neg
# FAIL neg
# {'Pos Words': 2, 'Neg Words': 2, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# VOLATILE neg
# CORRECTION neg
# IMPROVED pos
# CONCERN neg
# FAIL neg
# {'Pos Words': 1, 'Neg Words': 4, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# GREATER pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# TIGHTENING neg
# CORRECTION neg
# FORESTALL neg
# ADVERSE neg
# DISRUPTIONS neg
# IMPROVED pos
# STABILITY pos
# {'Pos Words': 2, 'Neg Words': 5, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRAINS neg
# SLOW neg
# CORRECTION neg
# FORESTALL neg
# ADVERSE neg
# DISRUPTIONS neg
# IMPROVED pos
# STABILITY pos
# AGAINST neg
# {'Pos Words': 2, 'Neg Words': 7, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# IMPROVE pos
# UNEMPLOYMENT neg
# UNEMPLOYMENT neg
# DISCONTINUED neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# SLOWING neg
# CORRECTION neg
# STRAINS neg
# IMPROVED pos
# DETERIORATION neg
# STABILITY pos
# AGAINST neg
# {'Pos Words': 2, 'Neg Words': 5, 'Word Count': 0}
# AGAINST neg
# ADVANCES pos
# AGAINST neg
# EFFICIENT pos
# NONCOMPETITIVE neg
# GAINED pos
# AGAINST neg
# ADVANCES pos
# AGAINST neg
# EFFICIENT pos
# STRESS neg
# NONCOMPETITIVE neg
# GAINED pos
# {'Pos Words': 6, 'Neg Words': 7, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# NONCOMPETITIVE neg
# {'Pos Words': 0, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 2, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# WEAKENING neg
# STRAINS neg
# DETERIORATE neg
# CONTRACTION neg
# AGAINST neg
# {'Pos Words': 0, 'Neg Words': 5, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 2, 'Word Count': 0}
# WINNING pos
# ERROR neg
# WINNING pos
# ERROR neg
# {'Pos Words': 2, 'Neg Words': 2, 'Word Count': 0}
# STRESS neg
# CONTRACTION neg
# AGAINST neg
# {'Pos Words': 0, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 2, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# IMPROVE pos
# EFFICIENCY pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# BOOST pos
# QUESTIONS neg
# BOOST pos
# QUESTIONS neg
# BOOST pos
# QUESTIONS neg
# BOOST pos
# QUESTIONS neg
# QUESTIONS neg
# {'Pos Words': 4, 'Neg Words': 5, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# WEAKENED neg
# SLOWED neg
# STRESS neg
# TIGHTENING neg
# CONTRACTION neg
# EASING neg
# STABILITY pos
# AGAINST neg
# {'Pos Words': 1, 'Neg Words': 7, 'Word Count': 0}
# EFFECTIVE pos
# EFFECTIVE pos
# {'Pos Words': 2, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 2, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# WEAK neg
# STRESS neg
# CONTRACTION neg
# IMPROVED pos
# EASING neg
# EASING neg
# STABILITY pos
# AGAINST neg
# {'Pos Words': 2, 'Neg Words': 6, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# PERSISTENT neg
# IMPROVED pos
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# STRESS neg
# CONTRACTION neg
# EASING neg
# DIMINISHED neg
# STABILITY pos
# AGAINST neg
# {'Pos Words': 1, 'Neg Words': 5, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 3, 'Word Count': 0}
# WINNING pos
# ERROR neg
# {'Pos Words': 1, 'Neg Words': 1, 'Word Count': 0}
# CLOSING neg
# CLOSING neg
# WINNING pos
# ERROR neg
# ...
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# GAIN pos
# {'Pos Words': 3, 'Neg Words': 4, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# PENALTY neg
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# GAIN pos
# {'Pos Words': 3, 'Neg Words': 4, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# GAINS pos
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DIMINISH neg
# ADVANCING pos
# SLOW neg
# DECLINES neg
# DECLINED neg
# STABLE pos
# STABILITY pos
# IMPROVES pos
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# PROGRESS pos
# PROGRESS pos
# SLOWER neg
# AGAINST neg
# IMPROVEMENT pos
# UNDUE neg
# STRESS neg
# IMPROVEMENT pos
# {'Pos Words': 13, 'Neg Words': 10, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# STRONG pos
# GAINS pos
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DIMINISH neg
# DECLINES neg
# BOOSTED pos
# ADVANCING pos
# SLOW neg
# DECLINED neg
# DECLINES neg
# DECLINED neg
# STABLE pos
# STABILITY pos
# DECLINE neg
# IMPROVES pos
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# PROGRESS pos
# PROGRESS pos
# SLOWER neg
# {'Pos Words': 13, 'Neg Words': 10, 'Word Count': 0}
# LAG neg
# OPPORTUNITY pos
# GAIN pos
# {'Pos Words': 2, 'Neg Words': 1, 'Word Count': 0}
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# GAIN pos
# {'Pos Words': 3, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# GAIN pos
# {'Pos Words': 3, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# STRONG pos
# GAINS pos
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DIMINISH neg
# DECLINES neg
# BOOSTED pos
# ADVANCING pos
# SLOW neg
# WEAKENED neg
# DECLINED neg
# DECLINES neg
# STABLE pos
# STABILITY pos
# IMPROVES pos
# DECLINES neg
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# IMPROVEMENT pos
# CONFIDENT pos
# {'Pos Words': 13, 'Neg Words': 9, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# SLOWED neg
# GAINS pos
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DECLINED neg
# DECLINES neg
# SLOW neg
# DECLINED neg
# DECLINES neg
# STABLE pos
# STABILITY pos
# SLOWED neg
# IMPROVES pos
# DECLINES neg
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# IMPROVEMENT pos
# CONFIDENT pos
# {'Pos Words': 9, 'Neg Words': 10, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# OPPORTUNITY pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# GAINS pos
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DIMINISHED neg
# IMPROVEMENT pos
# DECLINES neg
# STABILIZED pos
# STABLE pos
# STABILITY pos
# IMPROVES pos
# DECLINES neg
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# IMPROVEMENT pos
# CONFIDENT pos
# {'Pos Words': 11, 'Neg Words': 5, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# INADVERTENTLY neg
# EASILY pos
# INADVERTENTLY neg
# UNEMPLOYMENT neg
# INADVERTENTLY neg
# {'Pos Words': 1, 'Neg Words': 4, 'Word Count': 0}
# IMPROVEMENT pos
# IMPROVE pos
# GAINS pos
# DECLINING neg
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DIMINISHED neg
# DECLINES neg
# STABLE pos
# STABILITY pos
# IMPROVES pos
# DECLINES neg
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# IMPROVEMENT pos
# CONFIDENT pos
# {'Pos Words': 11, 'Neg Words': 6, 'Word Count': 0}
# OPPORTUNITY pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# IMPROVE pos
# GAINS pos
# DECLINING neg
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DIMINISHED neg
# DECLINES neg
# STABLE pos
# STABILITY pos
# DOWNWARD neg
# IMPROVES pos
# DECLINES neg
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# IMPROVEMENT pos
# CONFIDENT pos
# AGAINST neg
# {'Pos Words': 11, 'Neg Words': 8, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# GAINS pos
# SLOWED neg
# UNEMPLOYMENT neg
# UNDERUTILIZATION neg
# DIMINISHED neg
# DECLINES neg
# STABLE pos
# STABILITY pos
# IMPROVES pos
# DECLINES neg
# PROGRESS pos
# STABILITY pos
# PROGRESS pos
# IMPROVEMENT pos
# CONFIDENT pos
# AGAINST neg
# {'Pos Words': 10, 'Neg Words': 7, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# OPPORTUNITY pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# OPPORTUNITY pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# GAINS pos
# DECLINING neg
# UNEMPLOYMENT neg
# IMPROVEMENT pos
# UNDERUTILIZATION neg
# DIMINISHED neg
# DECLINES neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# STRENGTHENS pos
# IMPROVEMENT pos
# CONFIDENT pos
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# {'Pos Words': 10, 'Neg Words': 7, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# SLOWED neg
# LATE neg
# IMPROVED pos
# SLOWED neg
# STRONG pos
# GAINS pos
# DECLINE neg
# UNDERUTILIZATION neg
# DECLINES neg
# DECLINED neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# DECLINES neg
# STRENGTHENS pos
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# {'Pos Words': 9, 'Neg Words': 10, 'Word Count': 0}
# OPPORTUNITY pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# DESPITE pos
# IMPROVED pos
# STRONG pos
# GAINS pos
# STRENGTHENING pos
# DECLINES neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# DECLINES neg
# STRENGTHENS pos
# AGAINST neg
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# AGAINST neg
# {'Pos Words': 10, 'Neg Words': 6, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVED pos
# SLOWED neg
# IMPROVED pos
# STRONG pos
# GAINS pos
# STRENGTHENING pos
# DECLINES neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# DECLINES neg
# STRENGTHENS pos
# AGAINST neg
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# AGAINST neg
# {'Pos Words': 10, 'Neg Words': 7, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# IMPROVEMENT pos
# SLOWED neg
# UNEMPLOYMENT neg
# DECLINED neg
# GAINS pos
# DIMINISHED neg
# STRENGTHENED pos
# IMPROVE pos
# DRAG neg
# DECLINES neg
# DECLINED neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# DECLINES neg
# STRENGTHENS pos
# AGAINST neg
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# {'Pos Words': 9, 'Neg Words': 11, 'Word Count': 0}
# ADVERSE neg
# {'Pos Words': 0, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHENED pos
# GAINS pos
# STRONG pos
# WEAK neg
# DECLINES neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# DECLINES neg
# STRENGTHENS pos
# DIMINISHED neg
# AGAINST neg
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# AGAINST neg
# {'Pos Words': 8, 'Neg Words': 8, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# UNEMPLOYMENT neg
# GAINS pos
# DECLINES neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# DECLINES neg
# STRENGTHENS pos
# AGAINST neg
# STRENGTHENED pos
# PROGRESS pos
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# AGAINST neg
# {'Pos Words': 9, 'Neg Words': 7, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# UNEMPLOYMENT neg
# GAINS pos
# DECLINES neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# STRENGTHENS pos
# AGAINST neg
# STRENGTHEN pos
# PROGRESS pos
# IMPROVEMENT pos
# SHORTFALL neg
# PROGRESS pos
# AGAINST neg
# {'Pos Words': 9, 'Neg Words': 6, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# DECLINED neg
# DECLINES neg
# STABILITY pos
# STRENGTHEN pos
# DECLINES neg
# STRENGTHENS pos
# STRENGTHENING pos
# SHORTFALL neg
# PROGRESS pos
# {'Pos Words': 7, 'Neg Words': 5, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# IMPROVED pos
# LATE neg
# STABILITY pos
# STRENGTHEN pos
# STRENGTHENING pos
# SHORTFALL neg
# PROGRESS pos
# {'Pos Words': 7, 'Neg Words': 3, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRENGTHEN pos
# STABILIZE pos
# STRENGTHENING pos
# AGAINST neg
# {'Pos Words': 6, 'Neg Words': 2, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# SLOWED neg
# GAINS pos
# UNEMPLOYMENT neg
# DECLINED neg
# DECLINED neg
# STABILITY pos
# SLOWING neg
# STRENGTHEN pos
# STABILIZE pos
# STRENGTHENING pos
# {'Pos Words': 6, 'Neg Words': 5, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# DECLINED neg
# DECLINED neg
# STABILITY pos
# STRENGTHEN pos
# STABILIZE pos
# STRENGTHENING pos
# AGAINST neg
# {'Pos Words': 6, 'Neg Words': 4, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# DECLINED neg
# DECLINED neg
# STABILITY pos
# STRENGTHEN pos
# STABILIZE pos
# STRENGTHENING pos
# {'Pos Words': 6, 'Neg Words': 3, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# DECLINED neg
# STABILITY pos
# DEVASTATED neg
# SEVERE neg
# HARDSHIP neg
# DISRUPTIONS neg
# STRENGTHEN pos
# AFTERMATH neg
# BOOST pos
# STABILIZE pos
# STRENGTHENING pos
# {'Pos Words': 7, 'Neg Words': 7, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# DESPITE pos
# DISRUPTIONS neg
# UNEMPLOYMENT neg
# DECLINED neg
# AFTERMATH neg
# DECLINED neg
# STABILITY pos
# DISRUPTIONS neg
# STRENGTHEN pos
# STABILIZE pos
# STRENGTHENING pos
# {'Pos Words': 6, 'Neg Words': 6, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# DECLINED neg
# DECLINED neg
# STABILITY pos
# DISRUPTIONS neg
# STRONG pos
# STABILIZE pos
# STRONG pos
# AGAINST neg
# {'Pos Words': 6, 'Neg Words': 5, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRONG pos
# STABILIZE pos
# STRONG pos
# {'Pos Words': 6, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# STRONG pos
# STABILITY pos
# STRENGTHENED pos
# STRONG pos
# STABILIZE pos
# STRONG pos
# {'Pos Words': 9, 'Neg Words': 1, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# STRONG pos
# STABILITY pos
# STRONG pos
# STRONG pos
# {'Pos Words': 7, 'Neg Words': 1, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# DECLINED neg
# STABILITY pos
# STRONG pos
# STRONG pos
# {'Pos Words': 6, 'Neg Words': 2, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# STRONG pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRONG pos
# STRONG pos
# {'Pos Words': 7, 'Neg Words': 1, 'Word Count': 0}
# OPPORTUNITY pos
# CLOSING neg
# PENALTY neg
# FORFEITURE neg
# ABLE pos
# {'Pos Words': 2, 'Neg Words': 3, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# STRONG pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRONG pos
# {'Pos Words': 6, 'Neg Words': 1, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# STRONG pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# DECLINED neg
# STABILITY pos
# STRONG pos
# {'Pos Words': 6, 'Neg Words': 2, 'Word Count': 0}
# STABILITY pos
# GOOD pos
# BEST pos
# {'Pos Words': 3, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# STRONG pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRONG pos
# {'Pos Words': 6, 'Neg Words': 1, 'Word Count': 0}
# EFFECTIVE pos
# {'Pos Words': 1, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# STRENGTHEN pos
# GAINS pos
# STRONG pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRONG pos
# {'Pos Words': 5, 'Neg Words': 1, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}
# {'Pos Words': 0, 'Neg Words': 0, 'Word Count': 0}

# %%
word_list
# Out:
# ['THE',
#  'FEDERAL',
#  'OPEN',
#  'MARKET',
#  'COMMITTEE',
#  'HA',
#  'DECIDED',
#  'TO',
#  'LOWER',
#  'IT',
#  'TARGET',
#  'FOR',
#  'THE',
#  'FEDERAL',
#  'FUND',
#  'RATE',
#  '75',
#  'BASIS',
#  'POINT',
#  'TO',
#  '3-1/2',
#  'PERCENT',
#  'THE',
#  'COMMITTEE',
#  'TOOK',
#  'THIS',
#  'ACTION',
#  'IN',
#  'VIEW',
#  'OF',
#  'A',
#  'WEAKENING',
#  'OF',
#  'THE',
#  'ECONOMIC',
#  'OUTLOOK',
#  'AND',
#  'INCREASING',
#  'DOWNSIDE',
#  'RISK',
#  'TO',
#  'GROWTH',
#  'WHILE',
#  'STRAIN',
#  'IN',
#  'SHORT-TERM',
#  'FUNDING',
#  'MARKET',
#  'HAVE',
#  'EASED',
#  'SOMEWHAT',
#  'BROADER',
#  'FINANCIAL',
#  'MARKET',
#  'CONDITION',
#  'HAVE',
#  'CONTINUED',
#  'TO',
#  'DETERIORATE',
#  'AND',
#  'CREDIT',
#  'HA',
#  'TIGHTENED',
#  'FURTHER',
#  'FOR',
#  'SOME',
#  'BUSINESS',
#  'AND',
#  'HOUSEHOLD',
#  'MOREOVER',
#  'INCOMING',
#  'INFORMATION',
#  'INDICATES',
#  'A',
#  'DEEPENING',
#  'OF',
#  'THE',
#  'HOUSING',
#  'CONTRACTION',
#  'A',
#  'WELL',
#  'A',
#  'SOME',
#  'SOFTENING',
#  'IN',
#  'LABOR',
#  'MARKET',
#  'THE',
#  'COMMITTEE',
#  'EXPECTS',
#  'INFLATION',
#  'TO',
#  'MODERATE',
#  'IN',
#  'COMING',
#  'QUARTER',
#  'BUT',
#  'IT',
#  'WILL',
#  'BE',
#  'NECESSARY',
#  'TO',
#  'CONTINUE',
#  'TO',
#  'MONITOR',
#  'INFLATION',
#  'DEVELOPMENT',
#  'CAREFULLY',
#  'APPRECIABLE',
#  'DOWNSIDE',
#  'RISK',
#  'TO',
#  'GROWTH',
#  'REMAIN',
#  'THE',
#  'COMMITTEE',
#  'WILL',
#  'CONTINUE',
#  'TO',
#  'ASS',
#  'THE',
#  'EFFECT',
#  'OF',
#  'FINANCIAL',
#  'AND',
#  'OTHER',
#  'DEVELOPMENT',
#  'ON',
#  'ECONOMIC',
#  'PROSPECT',
#  'AND',
#  'WILL',
#  'ACT',
#  'IN',
#  'A',
#  'TIMELY',
#  'MANNER',
#  'A',
#  'NEEDED',
#  'TO',
#  'ADDRESS',
#  'THOSE',
#  'RISK',
#  'VOTING',
#  'FOR',
#  'THE',
#  'FOMC',
#  'MONETARY',
#  'POLICY',
#  'ACTION',
#  'WERE',
#  'BEN',
#  'S',
#  'BERNANKE',
#  'CHAIRMAN',
#  'TIMOTHY',
#  'F',
#  'GEITHNER',
#  'VICE',
#  'CHAIRMAN',
#  'CHARLES',
#  'L',
#  'EVANS',
#  'THOMAS',
#  'M',
#  'HOENIG',
#  'DONALD',
#  'L',
#  'KOHN',
#  'RANDALL',
#  'S',
#  'KROSZNER',
#  'ERIC',
#  'S',
#  'ROSENGREN',
#  'AND',
#  'KEVIN',
#  'M',
#  'WARSH',
#  'VOTING',
#  'AGAINST',
#  'WA',
#  'WILLIAM',
#  'POOLE',
#  'WHO',
#  'DID',
#  'NOT',
#  'BELIEVE',
#  'THAT',
#  'CURRENT',
#  'CONDITION',
#  'JUSTIFIED',
#  'POLICY',
#  'ACTION',
#  'BEFORE',
#  'THE',
#  'REGULARLY',
#  'SCHEDULED',
#  'MEETING',
#  'NEXT',
#  'WEEK',
#  'ABSENT',
#  'AND',
#  'NOT',
#  'VOTING',
#  'WA',
#  'FREDERIC',
#  'S',
#  'MISHKIN',
#  'IN',
#  'A',
#  'RELATED',
#  'ACTION',
#  'THE',
#  'BOARD',
#  'OF',
#  'GOVERNORS',
#  'APPROVED',
#  'A',
#  '75-BASIS-POINT',
#  'DECREASE',
#  'IN',
#  'THE',
#  'DISCOUNT',
#  'RATE',
#  'TO',
#  '4',
#  'PERCENT',
#  'IN',
#  'TAKING',
#  'THIS',
#  'ACTION',
#  'THE',
#  'BOARD',
#  'APPROVED',
#  'THE',
#  'REQUEST',
#  'SUBMITTED',
#  'BY',
#  'THE',
#  'BOARDS',
#  'OF',
#  'DIRECTORS',
#  'OF',
#  'THE',
#  'FEDERAL',
#  'RESERVE',
#  'BANKS',
#  'OF',
#  'CHICAGO',
#  'AND',
#  'MINNEAPOLIS',
#  '20080122']

# %%
with open('./scraped_data/20190130.csv') as f:
    s = f.read()

    blob=TextBlob(s)


#lista = [word for word in blob.words if word not in stopwords.words('english')]
#text = ' '.join(lista)
#blob = TextBlob(text)
word_list = [word.lemmatize().upper() for word in blob.words]

print(sentiment_check(fin_pos_words,fin_neg_words,word_list))
# Out:
# STRENGTHEN pos
# GAIN pos
# STRONG pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRONG pos
# {'Pos Words': 5, 'Neg Words': 1, 'Word Count': 0}

# %%
test_text = 'Achieve able no accomplishment creative test septum delight. Abandoned abnormal a.'
#test_text = ' '.join(lista)
#test_text = [word for word in test_text if len(word)>1]
test_blob=TextBlob(test_text)
#article = [word.lemmatize().upper() for word in blob.words]
test_article = [word.upper() for word in test_blob.words]
test_list = [word for word in test_article if word not in stopwords.words('english')]

# %%
test_list
# Out:
# ['ACHIEVE',
#  'ABLE',
#  'NO',
#  'ACCOMPLISHMENT',
#  'CREATIVE',
#  'TEST',
#  'SEPTUM',
#  'DELIGHT',
#  'ABANDONED',
#  'ABNORMAL',
#  'A']

# %%
print(sentiment_check(fin_pos_words,fin_neg_words,word_list))
# Out:
# STRENGTHEN pos
# GAIN pos
# STRONG pos
# UNEMPLOYMENT neg
# STABILITY pos
# STRONG pos
# {'Pos Words': 5, 'Neg Words': 1, 'Word Count': 319}

# %% [markdown]
# Code to read Central Bank sentiment dictionary (Garud, Londono, and Mislang 2017)

# %%
cb_words = pd.read_excel('ifdp1203-appendix.xlsx',sheet_name='1 FS Dictionary')
cb_pos_words = cb_words[cb_words['Positive']==1]['Word']
cb_pos_words = [word.upper() for word in cb_pos_words]
cb_neg_words = cb_words[cb_words['Negative']==1]['Word']
cb_neg_words = [word.upper() for word in cb_neg_words]

# %%
print(sentiment_check(cb_pos_words,cb_neg_words,word_list))
# Out:
# SOLID pos
# GAIN pos
# GROW pos
# {'Pos Words': 3, 'Neg Words': 0, 'Word Count': 319}

# %%
sentiment_check(cb_pos_words,cb_neg_words,word_list)['Pos Words']
# Out:
# SOLID pos
# GAIN pos
# GROW pos
# 3

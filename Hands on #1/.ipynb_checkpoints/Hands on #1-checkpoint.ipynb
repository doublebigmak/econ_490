# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
lfs_jan = pd.read_table("lfs_01_2015.tab", sep= '\t')

# %%
lfs_jan
# Out:
#         REC_NUM  SURVYEAR  SURVMNTH  LFSSTAT  PROV  CMA  AGE_12  AGE_6  SEX  \
# 0             1      2015         1        1    11    4      12    NaN    2
# 1             2      2015         1        6    24    4      11    NaN    1
# 2             3      2015         1        1    35    4       7    NaN    1
# 3             4      2015         1        4    59    4       3    5.0    1
# 4             5      2015         1        1    24    4       4    NaN    1
# 5             6      2015         1        1    46    4       7    NaN    2
# 6             7      2015         1        6    35    4      12    NaN    1
# 7             8      2015         1        1    59    3       9    NaN    1
# 8             9      2015         1        1    47    4      12    NaN    1
# 9            10      2015         1        1    35    4      11    NaN    2
# 10           11      2015         1        1    59    3       2    4.0    1
# ...

# %%
lfs_jan.describe()
# Out:
#              REC_NUM  SURVYEAR  SURVMNTH        LFSSTAT           PROV  \
# count  102762.000000  102762.0  102762.0  102762.000000  102762.000000
# mean    51381.500000    2015.0       1.0       3.014159      35.203918
# std     29664.978518       0.0       0.0       2.358880      14.603083
# min         1.000000    2015.0       1.0       1.000000      10.000000
# 25%     25691.250000    2015.0       1.0       1.000000      24.000000
# 50%     51381.500000    2015.0       1.0       1.000000      35.000000
# 75%     77071.750000    2015.0       1.0       6.000000      47.000000
# max    102762.000000    2015.0       1.0       6.000000      59.000000
#
#                  CMA         AGE_12         AGE_6            SEX  \
# count  102762.000000  102762.000000  22414.000000  102762.000000
# mean        3.717493       6.932679      3.590524       1.515015
# std         0.757273       3.506167      1.693034       0.499777
# min         1.000000       1.000000      1.000000       1.000000
# ...

# %%
lfs_jan.head()
# Out:
#    REC_NUM  SURVYEAR  SURVMNTH  LFSSTAT  PROV  CMA  AGE_12  AGE_6  SEX  \
# 0        1      2015         1        1    11    4      12    NaN    2
# 1        2      2015         1        6    24    4      11    NaN    1
# 2        3      2015         1        1    35    4       7    NaN    1
# 3        4      2015         1        4    59    4       3    5.0    1
# 4        5      2015         1        1    24    4       4    NaN    1
#
#    MARSTAT   ...     SPED7689  SPED1990  SP_SOC80  SP_NOCS01  SP_UHRSM  \
# 0        1   ...          NaN       3.0       NaN        NaN       NaN
# 1        1   ...          NaN       2.0       NaN        NaN       NaN
# 2        1   ...          NaN       5.0       NaN        5.0       4.0
# 3        6   ...          NaN       NaN       NaN        NaN       NaN
# 4        2   ...          NaN       5.0       NaN       10.0       4.0
#
#    SP_UHRST  SP_COWM  AGYOWNKN  SCH1624  FWEIGHT
# 0       NaN      0.0       NaN      NaN       44
# ...

# %%
lfs_jan['HRLYEARN'].describe()
# Out:
# count    50968.000000
# mean        24.438470
# std         12.623649
# min          2.310000
# 25%         15.000000
# 50%         21.150000
# 75%         31.000000
# max        144.510000
# Name: HRLYEARN, dtype: float64

# %%
lfs_jan[lfs_jan['SEX']==1]['HRLYEARN'].describe()
# Out:
# count    25075.000000
# mean        26.408024
# std         13.400958
# min          2.310000
# 25%         16.250000
# 50%         23.500000
# 75%         33.815000
# max        144.510000
# Name: HRLYEARN, dtype: float64

# %%
lfs_jan[lfs_jan['SEX']==2]['HRLYEARN'].describe()
# Out:
# count    25893.000000
# mean        22.531139
# std         11.505556
# min          3.080000
# 25%         13.500000
# 50%         19.950000
# 75%         28.000000
# max        105.770000
# Name: HRLYEARN, dtype: float64

# %%
list(lfs_jan)
# Out:
# ['REC_NUM',
#  'SURVYEAR',
#  'SURVMNTH',
#  'LFSSTAT',
#  'PROV',
#  'CMA',
#  'AGE_12',
#  'AGE_6',
#  'SEX',
#  'MARSTAT',
#  'ED76to89',
#  'EDUC90',
#  'MJH',
#  'EVERWORK',
#  'FTPTLAST',
#  'COWMAIN',
#  'NAICS_18',
#  'NAICS_43',
#  'SOC80_49',
#  'SOC80_21',
#  'NOCS_01_25',
#  'NOCS_01_47',
#  'YABSENT',
#  'WKSAWAY',
#  'PAYAWAY',
#  'UHRSMAIN',
#  'AHRSMAIN',
#  'FTPTMAIN',
#  'UTOTHRS',
#  'ATOTHRS',
#  'HRSAWAY',
#  'YAWAY',
#  'PAIDOT',
#  'UNPAIDOT',
#  'XTRAHRS',
#  'WHYPTOLD',
#  'WHYPTNEW',
#  'TENURE',
#  'PREVTEN',
#  'HRLYEARN',
#  'UNION',
#  'PERMTEMP',
#  'ESTSIZE',
#  'FIRMSIZE',
#  'DURUNEMP',
#  'FLOWUNEM',
#  'UNEMFTPT',
#  'WHYLEFTO',
#  'WHYLEFTN',
#  'DURJLESS',
#  'AVAILABL',
#  'LKPUBAG',
#  'LKEMPLOY',
#  'LKRELS',
#  'LKATADS',
#  'LKANSADS',
#  'LKOTHER',
#  'PRIORACT',
#  'YNOLKOLD',
#  'YNOLOOK',
#  'TLOLOOK',
#  'SCHOOLN',
#  'RELREFN',
#  'EFAMTYPE',
#  'EFAMSIZE',
#  'EFAMEMPL',
#  'EFAMUNEM',
#  'SP_AGE',
#  'SP_LFSST',
#  'SPED7689',
# ...

# %%
lfs_jan[lfs_jan['SEX']==2]['HRLYEARN']
# Out:
# 0         11.00
# 5         18.00
# 9         28.00
# 11        26.44
# 12          NaN
# 13          NaN
# 14        55.29
# 15          NaN
# 16        12.50
# 17        50.00
# 19          NaN
# 20        11.00
# 21        50.48
# 22        21.00
# 23        20.00
# 25        34.62
# 26        25.00
# 27        36.06
# 29          NaN
# 33          NaN
# 35          NaN
# 37          NaN
# 39          NaN
# 42          NaN
# 44          NaN
# 47        20.00
# 48          NaN
# 49          NaN
# 50          NaN
# 51        11.50
#           ...
# 102689    11.00
# 102691    14.00
# 102692      NaN
# 102693      NaN
# 102695      NaN
# 102699    16.63
# 102701      NaN
# 102702      NaN
# 102703    19.23
# 102706    11.50
# 102710      NaN
# 102715      NaN
# 102716      NaN
# 102719    12.00
# 102722    11.85
# 102725      NaN
# 102729      NaN
# 102730    11.00
# 102731    40.00
# 102732      NaN
# 102733    12.25
# 102737      NaN
# 102742    16.00
# 102746    33.00
# ...

# %%
male_earn = lfs_jan[lfs_jan['SEX']==1]['HRLYEARN']

# %%
female_earn = lfs_jan[lfs_jan['SEX']==2]['HRLYEARN']

# %%
male_earn.hist(bins=20)

# %%
female_earn.hist(bins=20)

# %%
male_earn.min()
# Out:
# 2.31

# %%
female_earn.min()
# Out:
# 3.08

# %%
ax1 = male_earn.hist(bins=20)

# %%
female_earn.hist(bins=20, ax = ax1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-0233d69d059b> in <module>
# ----> 1 female_earn.hist(bins=20, ax = ax1)
#
# ~\Anaconda3\envs\econ_490\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2476             ax = fig.gca()
#    2477         elif ax.get_figure() != fig:
# -> 2478             raise AssertionError('passed axis not bound to passed figure')
#    2479         values = self.dropna().values
#    2480
#
# AssertionError: passed axis not bound to passed figure

# %%
a = plt.axes([.65, .6, .2, .2], facecolor='k')

# %%
male_earn.hist(bins=20, ax = a)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-27-f775d2a1f82d> in <module>
# ----> 1 male_earn.hist(bins=20, ax = a)
#
# ~\Anaconda3\envs\econ_490\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2476             ax = fig.gca()
#    2477         elif ax.get_figure() != fig:
# -> 2478             raise AssertionError('passed axis not bound to passed figure')
#    2479         values = self.dropna().values
#    2480
#
# AssertionError: passed axis not bound to passed figure

# %%
fig1, ax1 = plt.subplots(figsize=(10,8))
male_earn.hist(bins=30, ax = ax1 )
female_earn.hist(bins=30, ax = ax1,fc=(0, 1, 1, 0.5))

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-29-a0b801b946e6> in <module>
# ----> 1 male_earn.hist(bins=20, ax = ax1)
#
# ~\Anaconda3\envs\econ_490\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2476             ax = fig.gca()
#    2477         elif ax.get_figure() != fig:
# -> 2478             raise AssertionError('passed axis not bound to passed figure')
#    2479         values = self.dropna().values
#    2480
#
# AssertionError: passed axis not bound to passed figure

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

#import modules

# %%
#import data
lfs_jan = pd.read_table("Hands on #1\lfs_01_2015.tab", sep= '\t')
lfs_jan
# Out:
#         REC_NUM  SURVYEAR  SURVMNTH  LFSSTAT  PROV  CMA  AGE_12  AGE_6  SEX  \
# 0             1      2015         1        1    11    4      12    NaN    2
# 1             2      2015         1        6    24    4      11    NaN    1
# 2             3      2015         1        1    35    4       7    NaN    1
# 3             4      2015         1        4    59    4       3    5.0    1
# 4             5      2015         1        1    24    4       4    NaN    1
# 5             6      2015         1        1    46    4       7    NaN    2
# 6             7      2015         1        6    35    4      12    NaN    1
# 7             8      2015         1        1    59    3       9    NaN    1
# 8             9      2015         1        1    47    4      12    NaN    1
# 9            10      2015         1        1    35    4      11    NaN    2
# 10           11      2015         1        1    59    3       2    4.0    1
# ...

# %%
list(lfs_jan)
# Out:
# ['REC_NUM',
#  'SURVYEAR',
#  'SURVMNTH',
#  'LFSSTAT',
#  'PROV',
#  'CMA',
#  'AGE_12',
#  'AGE_6',
#  'SEX',
#  'MARSTAT',
#  'ED76to89',
#  'EDUC90',
#  'MJH',
#  'EVERWORK',
#  'FTPTLAST',
#  'COWMAIN',
#  'NAICS_18',
#  'NAICS_43',
#  'SOC80_49',
#  'SOC80_21',
#  'NOCS_01_25',
#  'NOCS_01_47',
#  'YABSENT',
#  'WKSAWAY',
#  'PAYAWAY',
#  'UHRSMAIN',
#  'AHRSMAIN',
#  'FTPTMAIN',
#  'UTOTHRS',
#  'ATOTHRS',
#  'HRSAWAY',
#  'YAWAY',
#  'PAIDOT',
#  'UNPAIDOT',
#  'XTRAHRS',
#  'WHYPTOLD',
#  'WHYPTNEW',
#  'TENURE',
#  'PREVTEN',
#  'HRLYEARN',
#  'UNION',
#  'PERMTEMP',
#  'ESTSIZE',
#  'FIRMSIZE',
#  'DURUNEMP',
#  'FLOWUNEM',
#  'UNEMFTPT',
#  'WHYLEFTO',
#  'WHYLEFTN',
#  'DURJLESS',
#  'AVAILABL',
#  'LKPUBAG',
#  'LKEMPLOY',
#  'LKRELS',
#  'LKATADS',
#  'LKANSADS',
#  'LKOTHER',
#  'PRIORACT',
#  'YNOLKOLD',
#  'YNOLOOK',
#  'TLOLOOK',
#  'SCHOOLN',
#  'RELREFN',
#  'EFAMTYPE',
#  'EFAMSIZE',
#  'EFAMEMPL',
#  'EFAMUNEM',
#  'SP_AGE',
#  'SP_LFSST',
#  'SPED7689',
# ...

# %%
degree_map = {
    0:"no degree", 
    1:"elementary school",
    2:'high school',
    3:'university degree',
    4:'professional/trade degree',
    5:'graduate degree',
    6:'other'}
lfs_jan['highestDegree']= lfs_jan['EDUCLEV'].map(degree_map)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\econ_490\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EDUCLEV'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-4ab539a445a0> in <module>
#       7     5:'graduate degree',
# ...
